# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import os

# %%
pip install music21
# Out:
# Requirement already satisfied: music21 in /usr/local/lib/python3.10/dist-packages (9.1.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from music21) (5.2.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from music21) (1.3.2)
# Requirement already satisfied: jsonpickle in /usr/local/lib/python3.10/dist-packages (from music21) (3.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from music21) (3.7.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from music21) (10.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from music21) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from music21) (2.31.0)
# Requirement already satisfied: webcolors>=1.5 in /usr/local/lib/python3.10/dist-packages (from music21) (1.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->music21) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->music21) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->music21) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->music21) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->music21) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->music21) (1.16.0)

# %%
from music21 import *

# %%
def read_midi(file):
    print('loading music file:',file)
    notes=[]
    notes_to_parse=None
    midi = converter.parse(file)
    # grouping based on different instruments
    s2=instrument.partitionByInstrument(midi)

    for part in s2.parts:
        #select notes of piano
        if 'Piano' in str(part):
            notes_to_parse=part.recurse()
            # finding elemnet is a note or chord
            for element in notes_to_parse:

                #note
                if isinstance(element, note.Note):
                    notes.append(str(element.pitch))
                elif isinstance(element, chord.Chord):
                    notes.append('.'.join(str(n) for n in element.normalOrder))
    return np.array(notes)

# %%
path = '/content/drive/My Drive/dataset/'
files = [i for i in os.listdir(path) if i.endswith('.mid')]
notes_array = np.array([read_midi(path + i) for i in files])
# Out:
# loading music file: /content/drive/My Drive/dataset/schub_d760_1.mid
# /usr/local/lib/python3.10/dist-packages/music21/midi/translate.py:874: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, channel=None, data=b'Copyright \xa9 2004 by Bernd Kr\xfcger'>; getting generic Instrument
#   warnings.warn(
# loading music file: /content/drive/My Drive/dataset/schub_d760_3.mid
# loading music file: /content/drive/My Drive/dataset/schu_143_3.mid
# /usr/local/lib/python3.10/dist-packages/music21/midi/translate.py:874: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, channel=None, data=b'Copyright \xa9 1999 by Bernd Kr\xfcger'>; getting generic Instrument
#   warnings.warn(
# loading music file: /content/drive/My Drive/dataset/schub_d960_4.mid
# /usr/local/lib/python3.10/dist-packages/music21/midi/translate.py:874: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, channel=None, data=b'Copyright \xa9 2002 by Bernd Kr\xfcger'>; getting generic Instrument
#   warnings.warn(
# loading music file: /content/drive/My Drive/dataset/schubert_D850_4.mid
# /usr/local/lib/python3.10/dist-packages/music21/midi/translate.py:874: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=5, channel=None, data=b'Copyright \xa9 2010 by Bernd Krueger'>; getting generic Instrument
#   warnings.warn(
# loading music file: /content/drive/My Drive/dataset/schubert_D850_3.mid
# loading music file: /content/drive/My Drive/dataset/schubert_D935_1.mid
# /usr/local/lib/python3.10/dist-packages/music21/midi/translate.py:874: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=5, channel=None, data=b'Copyright \xa9 2007 by Bernd Krueger'>; getting generic Instrument
#   warnings.warn(
# loading music file: /content/drive/My Drive/dataset/schub_d760_2.mid
# loading music file: /content/drive/My Drive/dataset/schu_143_1.mid
# loading music file: /content/drive/My Drive/dataset/schu_143_2.mid
# loading music file: /content/drive/My Drive/dataset/schub_d960_2.mid
# loading music file: /content/drive/My Drive/dataset/schub_d760_4.mid
# loading music file: /content/drive/My Drive/dataset/schubert_D850_2.mid
# loading music file: /content/drive/My Drive/dataset/schub_d960_3.mid
# loading music file: /content/drive/My Drive/dataset/schubert_D850_1.mid
# /usr/local/lib/python3.10/dist-packages/music21/midi/translate.py:874: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=5, channel=None, data=b'Copyright \xa9 2009 by Bernd Krueger'>; getting generic Instrument
#   warnings.warn(
# loading music file: /content/drive/My Drive/dataset/schubert_D935_2.mid
# loading music file: /content/drive/My Drive/dataset/schub_d960_1.mid
# /usr/local/lib/python3.10/dist-packages/music21/midi/translate.py:874: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=5, channel=None, data=b'Copyright \xa9 2002 by Bernd Kr\xfcger'>; getting generic Instrument
#   warnings.warn(
# loading music file: /content/drive/My Drive/dataset/schumm-6.mid
# /usr/local/lib/python3.10/dist-packages/music21/midi/translate.py:874: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, channel=None, data=b'Copyright \xa9 1997 by Bernd Krueger'>; getting generic Instrument
#   warnings.warn(
# loading music file: /content/drive/My Drive/dataset/schumm-1.mid
# /usr/local/lib/python3.10/dist-packages/music21/midi/translate.py:874: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, channel=None, data=b'Copyright \xa9 1999 by Bernd Krueger'>; getting generic Instrument
#   warnings.warn(
# loading music file: /content/drive/My Drive/dataset/schumm-3.mid
# loading music file: /content/drive/My Drive/dataset/schumm-2.mid
# loading music file: /content/drive/My Drive/dataset/schubert_D935_4.mid
# loading music file: /content/drive/My Drive/dataset/schuim-3.mid
# loading music file: /content/drive/My Drive/dataset/schuim-4.mid
# /usr/local/lib/python3.10/dist-packages/music21/midi/translate.py:874: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, channel=None, data=b'Copyright \xa9 1996 by Bernd Krueger'>; getting generic Instrument
#   warnings.warn(
# loading music file: /content/drive/My Drive/dataset/schumm-4.mid
# loading music file: /content/drive/My Drive/dataset/schuim-1.mid
# loading music file: /content/drive/My Drive/dataset/schuim-2.mid
# loading music file: /content/drive/My Drive/dataset/schubert_D935_3.mid
# loading music file: /content/drive/My Drive/dataset/schumm-5.mid
# <ipython-input-8-ba0fb189e2a2>:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   notes_array = np.array([read_midi(path + i) for i in files])

# %%
notes_array[0]
# Out:
# array(['0.4.7', '7.0', '0.4.7', ..., '6.9', '0.3', '6.8'], dtype='<U8')

# %%
notes_=[element for note_ in notes_array for element in note_]
unique_notes=list(set(notes_))
len(unique_notes)
# Out:
# 345

# %%
unique_notes[0]
# Out:
# '2.4.7'

# %%
#importing library
from collections import Counter

#computing frequency of each note
freq = dict(Counter(notes_))

#library for visualiation
import matplotlib.pyplot as plt

#consider only the frequencies
no=[count for _,count in freq.items()]

#set the figure size
plt.figure(figsize=(5,5))

#plot
plt.hist(no)
# Out:
# (array([221.,  40.,  31.,  13.,   8.,   3.,   7.,   9.,   7.,   6.]),
#  array([1.0000e+00, 1.6170e+02, 3.2240e+02, 4.8310e+02, 6.4380e+02,
#         8.0450e+02, 9.6520e+02, 1.1259e+03, 1.2866e+03, 1.4473e+03,
#         1.6080e+03]),
#  <BarContainer object of 10 artists>)

# %%
frequent_notes = [note_ for note_, count in freq.items() if count>=50]
print(len(frequent_notes))
# Out:
# 182

# %%
new_music=[]
#it will only contains above most frequnetly used notes
for notes in notes_array:
    temp=[]
    for note_ in notes:
        if note_ in frequent_notes:
            temp.append(note_)
    new_music.append(temp)

new_music = np.array(new_music)
# Out:
# <ipython-input-14-1caafe6707a8>:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   new_music = np.array(new_music)

# %%
new_music.shape
# Out:
# (29,)

# %%
new_music
# Out:
# array([list(['0.4.7', '7.0', '0.4.7', '7.0', '0.4.7', '7.0', '0.4.7', '7.0', '0.4.7', '7.0', '0.4.7', '7.0', '0.4.7', '7.0', 'C3', 'E3', 'G3', 'C4', 'E4', 'G4', '11', '0', '0', '7', '11.2.5.7', '7', '11.2.5.7', '7', '11.2.5.7', '7', '11.2.5.7', '7', '11.2.5.7', '7', '11.2.5.7', '7', '11.2.5.7', '7', '11.2.5.7', '7', 'G3', 'B3', 'D4', 'F4', 'G4', 'B4', '1', '2', '2', '0.3.7', '7.0', '0.4.7', '7.0', 'G3', 'C4', 'E4', 'G4', 'C5', 'E5', '4.7', '0', '4.7', '4.7', '2.7', '11', '11', '2.7', '11', '7.0', '9', '0.6', '2', '0.6', '7.11', '7', 'G3', 'C4', 'E4', 'G4', 'C5', 'E5', '4.7', '0', '4.7', '4.7', '2.7', '11', '11', '2.7', '11', '7.0', '9', '0.6', '2', '0.6', '7.11', '7', 'C4', 'F4', 'A4', 'C5', 'F5', 'A5', '9.0', '5', '9.0', '9.0', '7.0', '4', '4', '7.0', '4', '0.5', '2', '5.11', '7', '5.11', '11.4', '0', '4.9', '5', '5', '9.2', '11', '2.8', '4', '2.8', '9.0', '9', '9.0', '9', '7', '4.9', 'F1', 'A5', 'F2', '4.9', 'F1', 'A5', 'F2', '4.9', 'F1', 'A5', 'F2', '4.9', 'F1', 'A5', 'F2', '4.9', 'F1', 'A5', 'F2', '4.9', 'F1', 'A5', 'F2', '4.9', 'F1', 'A5', 'F2', '4.9', 'F1', 'A5', 'F2', '3.9', 'F#2', 'A5', 'G2', '3.9', 'G#2', 'A5', 'A2', '3.9', 'B-2', 'A5', 'B2', '3.9', 'C3', 'A5', 'C#3', '3.9', 'D3', 'A5', 'E-3', '3.9', 'E3', 'A5', 'F3', '3.9', '5', '3.9', '5', '3.9', '5', '5', '5', '5', '5', '5', '5', '5', '4.8.11', '4', '4.8.11', '4', '0.4.7', '7.0', '0.4.7', '7.0', '0.4.7', '7.0', '0.4.7', '7.0', '0.4.7', '7.0', '0.4.7', '7.0', '0.4.7', '7.0', 'C3', 'E3', 'G3', 'C4', 'E4', 'G4', '11', '0', '0', '7', '11.2.5.7', '7', '11.2.5.7', '7.11.2', '11.2.5.7', '7', '11.2.5.7', '7', '11.2.5.7', '7', '11.2.5.7', '7', '11.2.5.7', '7', '11.2.5.7', '7', '11.2.5.7', '7', 'G3', 'B3', 'D4', 'F4', 'G4', 'B4', '1', '2', '2', '0.3.7', '7.0', '0.4.7', '7.0', '0.4.7', '7.0', 'G3', 'C4', 'E4', 'G4', 'C5', 'E5', '7.0', '9', '0.5', '9.0', '0.5', '9.0', 'A3', 'C4', 'F4', 'A4', 'C5', 'F5', '9.0', '4', '7.0', '4.7', '7.0', '4.7', '7.0', '4.7', 'C4', 'E4', 'G4', 'C5', 'E5', 'G5', '5.8.0', 'D2', 'F2', 'G#2', 'D3', 'F3', 'G#3', '2', '7.0', '4', '0', '7.11.2', '7', 'D4', 'G4', 'B4', 'D5', 'G5', 'B5', '5.8.0', 'D2', 'F2', 'G#2', 'D3', 'F3', 'G#3', '2', '7.0', '4', '0', '7.11.2', '7', 'G4', 'B4', 'D5', 'G5', 'B5', 'D6', '7.10.1', 'E3', 'G3', 'B-3', 'C#4', 'G4', 'B-4', 'C#5', 'E5', 'C#5', 'B-4', 'G4', 'E4', 'C#4', 'B-3', 'E6', 'C#4', 'G6', 'E4', 'E6', 'C#4', 'C#6', 'B-3', 'B-5', 'G3', 'G5', 'E3', 'E5', 'C#3', 'C#5', 'B-2', 'E5', 'C#3', 'G5', 'E3', 'E5', 'C#3', 'C#5', 'B-2', 'B-4', 'G2', 'G4', 'E2', 'E4', 'C#2', 'C#4', 'B-1', 'E4', 'C#2', 'G4', 'E2', 'E4', 'C#2', 'C#4', 'B-1', 'E4', 'C#2', 'G4', 'E2', 'E4', 'C#2', 'C#4', 'B-1', 'E4', 'C#2', 'G4', 'E2', 'E4', 'C#2', 'C#4', 'B-1', 'E4', 'C#2', 'G4', 'E2', 'E4', 'C#2', 'C#4', 'B-1', 'D4', 'B1', 'G4', 'D2', 'D4', 'G2', 'G3', 'D2', 'D4', 'B1', 'G4', 'D2', 'D4', 'G2', 'G3', 'D2', 'D4', 'B1', 'G4', 'D2', 'D4', 'G2', 'G3', 'D2', 'D4', 'B1', 'G4', 'D2', 'D4', 'G2', 'G3', 'D2', 'B3', 'C2', 'E4', 'E2', 'B4', 'A2', 'E4', 'E2', 'B3', 'C2', 'E4', 'E2', 'B4', 'A2', 'E4', 'E2', 'B3', 'C2', 'E4', 'E2', 'B4', 'A2', 'E4', 'E2', 'A3', 'C2', 'E4', 'E2', 'A4', 'A2', 'E4', 'E2', 'B3', 'D2', 'D4', 'G2', 'A4', 'B2', 'D4', 'G2', 'B3', 'D2', 'D4', 'G2', 'G4', 'B2', 'D4', 'G2', 'C4', 'D2', 'D4', 'A2', 'G4', 'C3', 'D4', 'A2', 'C4', 'D2', 'D4', 'A2', 'F#4', 'C3', 'D4', 'A2', '7.10.1', 'E3', 'G3', 'B-3', 'C#4', 'G4', 'B-4', 'C#5', 'E5', 'C#5', 'B-4', 'G4', 'E4', 'C#4', 'B-3', 'E6', 'C#4', 'G6', 'E4', 'E6', 'C#4', 'C#6', 'B-3', 'B-5', 'G3', 'G5', 'E3', 'E5', 'C#3', 'C#5', 'B-2', 'E5', 'C#3', 'G5', 'E3', 'E5', 'C#3', 'C#5', 'B-2', 'B-4', 'G2', 'G4', 'E2', 'E4', 'C#2', 'C#4', 'B-1', 'E4', 'C#2', 'G4', 'E2', 'E4', 'C#2', 'C#4', 'B-1', 'E4', 'C#2', 'G4', 'E2', 'E4', 'C#2', 'C#4', 'B-1', 'E4', 'C#2', 'G4', 'E2', 'E4', 'C#2', 'C#4', 'B-1', 'E4', 'C#2', 'G4', 'E2', 'E4', 'C#2', 'C#4', 'B-1', 'E4', 'B1', 'G4', 'E2', 'E4', 'G2', 'G3', 'E2', 'E4', 'B1', 'G4', 'E2', 'E4', 'G2', 'G3', 'E2', 'E4', 'B1', 'G4', 'E2', 'E4', 'G2', 'G3', 'E2', 'E4', 'B1', 'G4', 'E2', 'E4 ...
#        list(['G4', 'G3', 'G#4', 'G#3', 'E-4', 'E-3', 'C4', 'C3', 'G#3', 'G#2', 'G4', 'G3', 'G#4', 'G#3', 'E-4', 'E-3', 'C4', 'C3', 'G#3', 'G#2', '0.3', '3.8', '0.3', '3.8', '0.3', '3.8', '0.3', '3.8', '0.3', '3.8', '0.3', '3.8', '11.3', '3.8', 'C5', 'G#4', 'E-4', 'C4', 'E-4', 'G#4', 'C5', 'E-5', 'G#5', '9', '10', 'D4', 'D3', 'E-4', 'E-3', 'B-3', 'B-2', 'G3', 'G2', 'E-3', 'E-2', '1.3', '10.3', '1.3', '10.3', '1.3', '10.3', '1.3', '10.3', '1.3', '10.3', '1.3', '10.3', '0.3', '10.3', 'C#5', 'B-4', 'G4', 'E-4', 'G4', 'B-4', 'C#5', 'E-5', 'G5', '11', '0', '3.8', 'G4', 'G3', 'G#4', 'G#3', 'E-4', 'E-3', 'C4', 'C3', 'G#3', 'G#2', '3.6.8', 'G#2', 'A2', 'B-2', '3.6.8', 'B2', '3.6.8', 'C3', 'E5', 'C#3', 'F5', 'C#4', 'C#5', 'G#3', 'G#4', 'F3', 'F4', 'C#3', '0.3.5', 'F2', 'F#2', 'G2', '0.3.5', 'G#2', '0.3.5', 'A2', 'C5', 'B-2', 'C#5', 'B-3', 'B-4', 'F3', 'F4', 'C#3', 'C#4', 'B-2', 'C6', '7', 'C#6', 'B-5', 'G5', 'C#5', '1.4.7.10', 'B5', '8', 'C6', 'G#5', 'E-5', 'C5', '8.0.3', 'E-5', '10', 'E5', 'C#5', 'B-4', 'E4', '7.10.1', 'D5', '11', 'E-5', 'B4', 'G#4', 'E-4', '8.11.3', '3.8', 'E2', 'G#5', 'E3', '3.8', 'E2', 'G#5', 'E3', '3.8', 'E2', 'G#5', 'E3', '3.8', 'E2', 'G#5', 'E3', '3.8', 'E2', 'G#5', 'E3', '3.8', 'E2', 'G#5', 'E3', '2.8', 'F2', 'G#5', 'F#2', '2.8', 'G2', 'G#5', 'G#2', '2.8', 'A2', 'G#5', 'B-2', '2.8', 'B2', 'G#5', 'C3', '2.8', 'C#3', 'G#5', 'D3', '2.8', 'E-3', 'G#5', 'E3', '2.8', '4', '4', '4', '4', '4', '4', '3.7.10', '3', '3.7.10', '3', '3.7.10', '3', '3.7.10', '3', '0.3', '3.8', '0.3', '3.8', '0.3', '3.8', '0.3', '3.8', '0.3', '3.8', '0.3', '3.8', '11.3', '3.8', 'C5', 'G#4', 'E-4', 'C4', 'E-4', 'G#4', 'C5', 'E-5', 'G#5', '9', '10', 'D4', 'D3', 'E-4', 'E-3', 'B-3', 'B-2', 'G3', 'G2', 'E-3', 'E-2', '1.3', '10.3', '1.3', '10.3', '1.3', '10.3', '1.3', '10.3', '1.3', '10.3', '1.3', '10.3', '0.3', '10.3', 'C#5', 'B-4', 'G4', 'E-4', 'G4', 'B-4', 'C#5', 'E-5', 'G5', '11', '0', '3.8', 'G4', 'G3', 'G#4', 'G#3', 'E-4', 'E-3', 'C4', 'C3', 'G#3', 'G#2', 'G#4', '3.6.8', 'A4', 'B-4', 'B4', '3.6.8', 'C5', '3.6.8', 'C5', '1.5.8', 'C#5', 'G#5', '1.5', 'F4', '0.3.5', 'F#4', 'G4', 'G#4', '0.3.5', 'A4', '0.3.5', 'A4', '10.1.5', 'B-4', 'F5', '10.1', 'D5', 'E-3', 'E-5', '1.3', 'D4', 'G3', 'E-4', 'B-4', 'B4', 'E-3', 'C5', '0.3', 'D4', 'G#3', 'E-4', 'G#4', 'D5', 'E-3', 'E-5', '1.3', 'D4', 'G3', 'E-4', 'B-4', 'B4', 'E-3', 'C5', '0.3', 'D4', 'G#3', 'E-4', 'G#4', '3.8', '4', '3.8', '4', '3.8', '4', '3.8', '4', '3.8', '4', '3.8', '4', '2.8', 'F2', 'G#5', 'F#2', '2.8', 'G2', 'G#5', 'G#2', '2.8', 'A2', 'G#5', 'B-2', '2.8', 'B2', 'G#5', 'C3', '2.8', 'C#3', 'G#5', 'D3', '2.8', 'E-3', 'G#5', 'E3', '2.8', '4', '4', '4', '4', '4', '4', '3.7.10', '3', '3.7.10', '3', '3.7.10', '3', '3.7', '3', '1', '1', '1', '1', '1', '1', '4.7', '1', '10.1', '4.7', '10.1', '4.7', '4.7', '1', '7.10', '1.4', '1', '7.10', '1', '1.4', '4.7', '1', '10.1', '4.7', '10.1', '4.7', '4.7', '1', '7.10', '1.4', '1', '7.10', '1', '1.4', '4.7', '1', '4.7', '1', '4.7', '1', '4.8', '1', '4.8', '1', '4.8', '1', '4.7', '1', '4.7', '1', '4.7', '1', '4.8', '1', '4.8', '1', '4.8', '1', '1', '1', '1', '6.11', '3', '6.11', '3', '6.11', '3', '11.3.6', '6', '11.3.6', '6', '11.3.6', '6', '6', '6', '6', '11.3.6', '11', '11', '11', '11', '11', '11', '2.5', '11', '8.11', '2.5', '8.11', '2.5', '2.5', '11', '5.8', '11.2', '11', '5.8', '11', '11.2', '2.5', '11', '8.11', '2.5', '8.11', '2.5', '2.5', '11', '5.8', '11.2', '11', '5.8', '11', '11.2', 'F5', '6', 'B2', '11.3.6', '6', '6', '11', 'E-3', '11.3.6', '11', '11', '10', 'C#3', '10', '10', '4', 'F#2', '6.10.1', '3', 'B2', '11.3.6', '3', '11', '8', 'E2', '1.4.8', '8', '1', '10', 'F#2', '10', '1', '6', 'B-2', 'E-6', 'E6', 'F6', '6', 'B2', 'F#3', 'B3', '6', 'E-4', '6', 'B3', 'F#3', '11', 'E-3', 'B3', 'E-4', '11', 'F#4', '11', 'E-4', 'B3', '10', 'C#3', 'B-3', 'E4', '10', 'F#4', '10', 'E4', 'B-3', '4', 'F#2', 'B-3', 'C#4', 'F#4', 'C#4', 'B-3', '3', 'B2', 'B3', 'E-4', '3', 'F#4', '11', 'E-4', 'B3', '8', 'E2', 'G#3', 'C#4', '8', 'E4', '1', 'C#4', 'G#3', '10', 'F#2', 'F ...
#        list(['A4', 'B4', 'C5', 'B4', 'C5', 'D5', 'E5', 'E4', 'F#4', 'G#4', 'A4', 'F#4', 'B4', 'G#4', 'C5', 'A4', 'B4', 'C5', 'D5', 'E5', 'E4', 'F#4', 'G#4', 'A4', 'F#4', 'B4', 'G#4', 'C5', 'A4', 'B4', 'C5', 'D5', 'C5', 'A4', 'D5', 'B4', 'E5', 'C5', 'F5', 'D5', 'G5', 'E5', 'A5', 'F5', 'G5', 'E5', 'F5', 'D5', 'E5', 'C5', 'D5', 'B4', 'C5', 'A4', 'B4', 'G4', 'A4', 'F4', 'B4', 'C5', 'B4', 'C4', 'A4', 'G4', 'F4', 'A3', 'E4', 'E-4', 'E4', 'G#3', 'F#3', 'E3', 'E-3', 'C#3', 'B2', 'B3', 'A3', 'C#4', 'E-4', 'E4', 'G#3', 'F#4', 'F#3', 'G#4', 'E3', 'A4', 'E-3', 'C#3', 'B2', 'B3', 'A3', 'C#4', 'E-4', 'E4', 'G#3', 'F#4', 'F#3', 'G#4', 'E3', 'A4', 'E-3', 'C#3', 'B2', 'B3', 'A3', 'C#4', 'E-4', 'E4', 'G#3', 'F#4', 'F#3', 'G#4', 'E3', 'F#4', 'F#3', 'G#4', 'E3', 'A4', 'E-3', 'G#4', 'E3', 'A4', 'E-3', 'B4', 'D3', 'A4', 'E3', 'B4', 'D3', 'C5', 'C3', 'B4', 'D3', 'C5', 'C3', 'D5', 'B2', 'C5', 'C3', 'D5', 'B2', 'E5', 'A2', 'F5', 'G#2', 'E5', 'A2', 'D5', 'B2', '5.11', '2.8', 'E5', 'A2', 'D5', 'B2', '5.11', '2.8', 'E5', 'A2', 'D5', 'B2', '5.11', '2.8', 'E5', 'A2', 'D5', 'B2', '5.11', '2.8', 'E5', 'A2', 'D5', 'B2', '5.11', '2.8', 'E5', 'A2', 'D5', 'B2', '5.11', '8', 'E5', 'D5', 'F5', 'E5', 'D5', 'F5', 'E5', 'D5', 'F5', 'E5', 'D5', 'E5', 'D5', 'C5', 'D5', 'C5', 'B4', 'A4', 'B4', 'C5', 'B4', 'C5', 'D5', 'E5', 'E4', 'F#4', 'G#4', 'A4', 'F#4', 'B4', 'G#4', 'C5', 'A4', 'B4', 'C5', 'D5', 'E5', 'E4', 'F#4', 'G#4', 'A4', 'F#4', 'B4', 'G#4', 'C5', 'A4', 'B4', 'C5', 'D5', 'C5', 'A4', 'D5', 'B4', 'E5', 'C5', 'F5', 'D5', 'G5', 'E5', 'A5', 'F5', 'G5', 'E5', 'F5', 'D5', 'E5', 'C5', 'D5', 'B4', 'C5', 'A4', 'B4', 'G4', 'A4', 'F4', 'B4', 'C5', 'B4', 'C4', 'A4', 'G4', 'F4', 'A3', 'E4', 'E-4', 'E4', 'G3', 'F#4', 'F#3', 'G4', 'E3', 'A4', 'E-3', 'C#3', 'B2', 'B3', 'A3', 'C#4', 'E-4', 'E4', 'G3', 'F#4', 'F#3', 'G4', 'E3', 'A4', 'E-3', 'C#3', 'B2', 'B3', 'A3', 'C#4', 'E-4', 'E4', 'G3', 'F#4', 'F#3', 'G4', 'E3', 'F#4', 'E-3', 'G4', 'E3', 'A4', 'F#3', 'G4', 'E3', 'A4', 'F#3', 'B4', 'G3', 'A4', 'F#3', 'B4', 'G3', 'C5', 'A3', 'B4', 'G#3', 'C5', 'A3', 'D5', 'B3', 'C5', 'A3', 'D5', 'B3', 'E5', 'C4', 'F4', 'D4', 'B-4', 'B-3', 'D5', 'F3', 'F5', 'D3', 'B-5', 'B-2', 'D6', 'F2', 'F6', 'D2', 'B-6', 'B-1', 'F1', '9.0.4', '9.0.4', '4.8.11', '4.8.11', 'A4', 'C4', 'B4', 'B3', 'C5', 'A3', 'D5', 'G#3', 'F#3', 'E3', 'E4', 'D4', 'F#4', 'G#4', 'A4', 'C4', 'B4', 'B3', 'C5', 'A3', 'D5', 'G#3', 'F#3', 'E3', 'E4', 'D4', 'F#4', 'G#4', 'A4', 'C4', 'B4', 'B3', 'C5', 'A3', 'B4', 'G#3', 'C5', 'A3', 'D5', 'B3', 'C5', 'A3', 'D5', 'B3', 'E5', 'C4', 'F4', 'D4', 'B-4', 'B-3', 'D5', 'F3', 'F5', 'D3', 'B-5', 'B-2', 'D6', 'F2', 'F6', 'D2', 'B-6', 'B-1', 'F1', '9.0.4', '9.0.4', '4.8.11', '4.8.11', '9.0.4', '9.0.4', '9.11', '0.2', '4.8', '4', '3.9', '5', '4.8', '4', '3.9', '5', '4.8', '4', '5.9.0', '5.9.0', '5.7', '9.11', '0.4', '0', '5.11', '2', '0.4', '0', '5.11', '2', '0.4', '0', '8', '9.0.4', '9', '10.2.5', '10', '11', '9.0.4', '0', '2', '9.0.4', '4', '4.8.11', '4', 'A4', '9.0.4', 'B4', 'C5', 'D5', 'E5', 'F#5', 'G#5', 'A5', 'B5', 'C6', 'D6', '4', '4.8', '3', '5.9', '4', '4.8', '3', '5.9', '4', '4.8', 'F4', '5.9.0', 'G4', 'A4', 'B-4', 'C5', 'D5', 'E5', 'F5', 'G5', 'A5', 'B-5', '0', '0.4', '11', '2.5', '0', '0.4', '11', '2.5', '0', '0.4', 'B4', 'C5', 'D5', 'E5', 'F5', 'B5', 'D6', 'F6', 'E6', '9.0.4', 'B-4', '10.2.5', 'D5', 'F5', 'B-5', 'D5', 'F5', 'G#5', 'D6', 'C5', '9.0.4', 'E5', 'A5', 'C6', 'B4', 'D5', 'F5', 'B5', 'A4', '9.0.4', 'C5', 'E5', 'A5', 'G#4', '4.8.11', 'B4', 'E5', 'G#5', 'A3', 'A2', 'B3', 'B2', 'C4', 'C3', 'D4', 'D3', 'E4', 'E3', 'F#4', 'F#3', 'G#4', 'G#3', 'A4', 'A3', 'B4', 'B3', 'C5', 'C4', 'D5', 'D4', 'E5', 'E4', 'F5', 'F4', 'G5', 'G4', 'A5', 'A4', 'B-5', 'B-4', 'G5', 'G4', 'E5', 'E4', 'C#5', 'C#4', 'C5', 'C4', 'A4', 'C4', 'F2', 'C3', 'F3', 'C3', 'F3', 'B-4', 'A4', 'G4', 'C4', 'E2', 'C3', 'B-4', 'G3', 'C3', 'C#5', 'B-3', 'C5', 'C4', 'F2', 'C3', 'A3', 'C3', 'A4', 'F3', 'C5', 'C4', 'E2', 'C3', 'E3', 'C3', 'B-4', 'G3', 'A4', 'C4', 'F2', 'C3', 'F3', 'C3', 'F3', 'B-4', 'A4', 'G4', 'C4', 'E2', 'C3', 'B-4 ...
#        list(['7', '7', 'D5', 'C5', 'G3', 'B4', 'G4', 'B4', '2.5', 'B4', 'G4', 'B4', 'G3', 'C5', 'G4', '0.3', 'E-5', 'G4', 'C5', 'G3', 'B4', 'G4', 'B4', '2.5', 'B4', 'G4', 'B4', 'G3', 'C5', 'G4', '0.3.6', 'E-5', 'F#4', 'C5', 'F3', 'B-4', 'F4', 'B-4', 'D4', 'B-4', 'F4', 'C5', 'G3', 'B-4', 'E4', 'B-4', 'C4', 'B-4', 'E4', 'C5', '2.5', 'B-4', 'A4', 'F4', 'B-4', 'C5', '3.5', 'D5', 'F4', 'B-4', '10.2', '7', '7', 'D6', 'C6', 'G3', 'B5', 'G4', 'B5', '2.5', 'B5', 'G4', 'B5', 'G3', 'C6', 'G4', '0.3', 'E-6', 'G4', 'C6', 'G3', 'B5', 'G4', 'B5', '2.5', 'B5', 'G4', 'B5', 'G3', 'C6', 'G4', '0.3.6', 'E-6', 'F#4', 'C6', 'F3', 'B-5', 'F4', 'B-5', 'D4', 'B-5', 'F4', 'C6', 'G3', 'B-5', 'E4', 'B-5', 'C4', 'B-5', 'E4', 'C6', '2.5', 'B-5', 'A5', 'F4', 'B-5', 'C6', '3.5', 'D6', 'F4', 'B-5', '10.2', 'A3', 'G3', 'D5', 'F3', 'G5', 'E-3', '7.10', 'E-5', 'C3', '7.0', 'C5', 'F3', '9.0', 'D5', 'E-3', 'E-5', '9.0', 'F5', 'D3', 'G5', 'F5', '5.10', 'E-5', 'D5', 'B-2', 'E-5', 'D5', '5.10', 'C5', 'B-4', 'E-3', '7.10', 'D3', 'B-4', '7.10', 'E-5', 'C3', '3.9', 'C5', 'A2', '3.9', 'A4', 'D3', '6.9', '2', 'F#2', '0', '2.6', '0', 'G2', '10', 'G3', '9', 'E-2', '7', 'E-3', '10', 'C2', '9', 'C3', '7', 'D2', '6', 'D3', '7', '0.3', '9.2', '2.6', '9.2', '2.6', '3', '2', '0', '0', 'G2', '10', 'G3', '9', 'E-2', '7', 'E-3', '8', 'C2', 'C3', '6', 'D2', 'D3', '7', '7', '7', '7', 'D5', 'C5', 'G3', 'B4', 'G4', 'B4', '2.5', 'B4', 'G4', 'B4', 'G3', 'C5', 'G5', 'G4', 'F5', '0.3', 'E-5', 'D5', 'G4', 'C5', 'C5', 'G3', 'B4', 'G4', 'B4', '2.5', 'B4', 'G4', 'B4', 'G3', 'C5', 'G4', '0.3.6', 'E-5', 'F#4', 'C5', 'F3', 'B-4', 'F4', 'B-4', 'D4', 'B-4', 'F4', 'C5', 'G3', 'B-4', 'E4', 'B-4', 'C4', 'B-4', 'E4', 'C5', '2.5', 'B-4', 'A4', 'F4', 'B-4', 'C5', '3.5', 'D5', 'F4', 'B-4', '10.2', 'A3', 'G3', 'D5', 'F3', 'G5', 'E-3', '7.10', 'E-5', 'C3', '7.0', 'C5', 'F3', '9.0', 'D5', 'E-3', 'E-5', '9.0', 'F5', 'D3', 'G5', 'F5', '5.10', 'E-5', 'D5', 'B-2', 'E-5', 'D5', '5.10', 'C5', 'B-4', 'E-3', '7.10', 'D3', 'B-4', '7.10', 'E-5', 'C3', '8.0', 'C5', 'E-3', '8.0', 'G#4', 'C3', '8.0', 'B-4', 'E-3', 'C5', '8.0', 'E-5', 'C#3', '7.10', 'C#5', 'E-3', 'C5', '7.10', 'B-4', 'C#3', '7.10', 'C5', 'E-3', 'C#5', '7.10', 'E-5', 'C3', 'F5', 'E-5', '8.0', 'C#5', 'C5', 'E-3', 'C#5', 'C5', '8.0', 'B-4', 'G#4', 'C3', '8.0', 'B-4', 'E-3', 'C5', '8.0', 'E-5', 'C#3', 'C#5', '7.10', 'C#5', 'E-3', 'E-5', 'C#5', '7.10', 'C5', 'B-4', 'C#3', 'E-5', '7.10', 'F5', 'E-3', 'G5', '7.10', '8', 'C3', '8.0', 'E-3', '8.0', '0', 'C3', '8.0', 'E-3', '8', '8.0', '8', 'C#3', '7.10', '7', 'E3', '7.10', '7', 'C#3', '7.10', '7', 'E3', '7.10', '7', 'D3', '10.2', '5', 'F3', '10.2', '10', 'D3', '10.2', 'F3', '9', '10.2', '9', 'E-3', '7', '0.3', '3', 'G3', '0.3', '2', 'F3', '10.2', '0', 'F3', '9.0', '10', 'B-2', '10.2', 'D5', 'D3', 'D5', '10.2', 'D5', 'D5', 'F3', 'D5', '10.2', 'D5', 'D5', 'F#3', 'C5', 'D5', '0.2', 'E-5', 'D5', '7.11.2', '7', '7', 'D6', 'C6', 'G3', 'B5', 'G4', 'B5', '2.5', 'B5', 'G4', 'B5', 'G3', 'C6', 'G6', 'G4', 'F6', '0.3', 'E-6', 'D6', 'G4', 'C6', 'C6', 'G3', 'B5', 'G4', 'B5', '2.5', 'B5', 'G4', 'B5', 'G3', 'C6', 'G4', '0.3.6', 'E-6', 'F#4', 'C6', 'F3', 'B-5', 'F4', 'B-5', 'D4', 'B-5', 'F4', 'C6', 'G3', 'B-5', 'E4', 'B-5', 'C4', 'B-5', 'E4', 'G5', '2.5', 'F5', 'E5', 'F4', 'F5', 'E-5', '5.9', 'C5', 'E-4', 'B-4', '10.2', 'D5', 'F4', 'F5', 'D4', 'B-5', 'B-3', 'D6', 'G3', 'C6', 'E4', 'C6', 'B-3', 'C6', 'E4', 'G5', 'F3', 'F5', 'E5', 'F4', 'F5', 'C5', 'A3', 'A4', 'F4', 'D6', 'G3', 'C6', 'E4', 'C6', 'B-3', 'C6', 'E4', 'G5', 'F3', 'F5', 'E5', 'F4', 'F5', 'C5', 'A3', 'A4', 'F4', 'A5', 'D3', 'G5', 'B3', 'G5', 'F3', 'G5', 'B3', 'D6', 'C3', 'C6', 'B5', 'C4', 'C6', 'G5', 'E3', 'E5', 'C4', 'A5', 'D3', 'G5', 'B3', 'G5', 'F3', 'G5', 'B3', 'D6', '0.4', 'C6', 'B5', 'C6', 'G5', 'E5', 'D5', 'C5', 'B4', 'C5', 'G4', 'E4', 'D4', 'C4', 'B3', 'C4', 'G3', 'E3', 'C3', 'G2', 'E2', 'D2', 'C2', '0.4.7', 'B-1', '9.0.4', 'A1', 'G1', 'C5', 'A4', 'F4', 'F1', 'A4', 'F5', 'A4', 'F4', 'F2', 'A4', 'C5', 'E5', 'A4', 'E4', 'A2', 'A4', 'B-4', 'D5', 'F4', 'D4', 'B-2', 'F4 ...
#        list(['2.6', '6.9', '2.6', '6.9', '2.6', '6.9', 'A5', '2.6', 'B5', 'A5', '6.9', 'F#5', 'D5', '2.6', 'D5', '6.9', 'D5', 'C#5', '4.7', 'B4', 'C#5', '7.9', 'E5', 'A4', '2.6', 'D5', '6.9', 'E5', '1.7', '7', 'B5', '7.9', 'A5', 'A5', '2.6', 'A5', '6.9', 'C#6', 'B5', '2.7', 'B-5', 'B5', '7.11.2', 'D6', 'A5', '2.6', '6.9', 'A5', '2.6', 'B5', 'A5', '6.9', 'F#5', 'D5', '2.6', 'D5', '6.9', 'C#5', '4.7', 'B4', 'C#5', '7.9', 'F#5', 'F#5', '6.10', '10.1', 'G5', '11.2', 'B5', 'E6', 'D6', '2.7', 'B5', 'G5', 'F#5', '2.6', 'F#5', '6.9', 'E5', '1.7', 'G5', 'B5', 'A5', '7.9', 'G5', 'C#5', 'D5', '2.6', 'D4', 'D3', 'F#4', 'F#3', 'B4', 'B3', 'A4', 'A3', 'F#4', 'F#3', 'D4', 'D3', '4.9', '1.7', '4.9', '7.9', 'E4', '1.7', 'G4', 'C#5', 'B4', '7.9', 'G4', 'E4', '2.6.9', '2.6', '6.9', 'D5', '2.6', 'F#5', 'B5', 'A5', '6.9', 'F#5', 'D5', 'C#5', '1.4', 'A4', 'F#5', 'E5', '9.1', 'C#5', 'A4', 'G#4', '11.2', 'E4', 'G#4', 'E5', '2.4', 'D5', 'B4', 'A4', '9.1', '1.4', '9.1.4', 'A3', 'C#4', 'F#4', '1.4', 'E4', 'C#4', 'A3', '2.6', 'A3', '11.2.4', 'G#3', '4.8.11', 'B3', 'D4', 'F#4', '11.2.4', 'E4', 'D4', 'B3', '6.9.1', 'C#4', '9.1.4', 'A3', '9.1.4', 'G3', 'C#4', 'F#4', '9.1.4', 'E4', 'C#4', 'G3', '9.2', 'F#3', 'A3', 'D4', '11.2', 'F3', 'A3', 'D4', '1.4', 'E3', 'A3', 'C#4', '2.4.8', 'E4', 'D4', 'B3', '9.1.4', 'A4', 'A3', '9.1', '8.11.2', '1.4.7', '2.6', '6.9', 'A5', '2.6', 'B5', 'A5', '6.9', 'F#5', 'D5', '2.6', 'D5', '6.9', 'D5', 'C#5', '4.7', 'B4', 'C#5', '7.9', 'E5', 'A4', '2.6', 'D5', '6.9', 'E5', '1.7', '7', 'B5', '7.9', 'A5', 'A5', '2.6', 'A5', '6.9', 'C#6', 'B5', '2.7', 'B-5', 'B5', '7.11.2', 'D6', 'A5', '2.6', '6.9', 'A5', '2.5', 'B-5', 'A5', '5.9', 'F5', 'D5', '2.5', 'D5', '5.9', 'D5', '5.9', '0.3.5', '5.9', '0.3.5', '5.10', '10.2.5', 'B-5', '2.5', 'D6', '10.2.5', 'E6', 'C#6', 'D6', 'E6', 'F6', 'A5', '2.6.9', 'A5', '6.9', 'E5', '7.9.1', 'G5', 'B5', 'A5', '7.9', 'G5', 'C#5', 'A5', '6.9', '2.6.9', 'G5', '7.11.2', 'B5', 'E6', 'D6', '2.7', 'B5', 'G5', 'F#5', '2.6', 'A5', 'A5', '6.9', 'E5', '1.7', 'G5', 'B5', 'A5', '7.9', 'G5', 'C#5', 'D5', '2.6', 'D4', 'D3', 'F#4', 'F#3', 'B4', 'B3', 'A4', 'A3', 'F#4', 'F#3', 'D4', 'D3', '4.9', '1.7', '4.9', '7.9', 'E4', '1.7', 'G4', 'C#5', 'B4', '7.9', 'G4', 'E4', '2.6.9', '2.6', '6.9', 'D5', '2.6', 'F#5', 'B5', 'A5', '6.9', 'F#5', 'D5', 'C#5', '1.4', 'A4', 'F#5', 'E5', '9.1', 'C#5', 'A4', 'G#4', '11.2', 'E4', 'G#4', 'E5', '2.4', 'D5', 'B4', 'A4', '9.1', '1.4', '9.1.4', 'A3', 'C#4', 'F#4', '1.4', 'E4', 'C#4', 'A3', '2.6', 'A3', '11.2.4', 'G#3', '4.8.11', 'B3', 'D4', 'F#4', '11.2.4', 'E4', 'D4', 'B3', '6.9.1', 'C#4', '9.1.4', 'A3', '9.1.4', 'G3', 'C#4', 'F#4', '9.1.4', 'E4', 'C#4', 'G3', '9.2', 'F#3', 'A3', 'D4', '11.2', 'F3', 'A3', 'D4', '1.4', 'E3', 'A3', 'C#4', '2.4.8', 'E4', 'D4', 'B3', '9.1.4', 'A4', 'A3', '9.1', '8.11.2', '1.4.7', '2.6', '6.9', 'A5', '2.6', 'B5', 'A5', '6.9', 'F#5', 'D5', '2.6', 'D5', '6.9', 'D5', 'C#5', '4.7', 'B4', 'C#5', '7.9', 'E5', 'A4', '2.6', 'D5', '6.9', 'E5', '1.7', '7', 'B5', '7.9', 'A5', 'A5', '2.6', 'A5', '6.9', 'C#6', 'B5', '2.7', 'B-5', 'B5', '7.11.2', 'D6', 'A5', '2.6', '6.9', 'A5', '2.5', 'B-5', 'A5', '5.9', 'F5', 'D5', '2.5', 'D5', '5.9', 'D5', '5.9', '0.3.5', '5.9', '0.3.5', '5.10', '10.2.5', 'B-5', '2.5', 'D6', '10.2.5', 'E6', 'C#6', 'D6', 'E6', 'F6', 'A5', '2.6.9', 'A5', '6.9', 'E5', '7.9.1', 'G5', 'B5', 'A5', '7.9', 'G5', 'C#5', 'A5', '6.9', '2.6.9', 'G5', '7.11.2', 'B5', 'E6', 'D6', '2.7', 'B5', 'G5', 'F#5', '2.6', 'A5', 'A5', '6.9', 'E5', '1.7', 'G5', 'B5', 'A5', '7.9', 'G5', 'C#5', 'D5', '2.6', 'D4', 'D3', 'E4', 'E3', 'F#4', 'F#3', 'G4', 'G3', 'G#4', 'G#3', 'A4', 'A3', 'G#4', 'G#3', 'A4', 'A3', '7.11', '7.11', '2.6.9', '9.2', 'D5', 'F#3', 'C#5', 'A3', 'B4', 'G3', 'A4', 'F#3', 'G4', 'A3', 'F#4', 'D4', 'A4', 'E4', 'G4', 'E4', 'A3', 'A4', 'G4', 'B4', 'C#5', 'F#4', 'D5', 'E-5', 'G4', 'E5', 'E-5', 'A4', 'E5', 'D5', 'F#4', 'E5', 'F#5', 'D4', 'G5', 'G#5', 'E4', 'A5', 'G#5', 'F#4', 'A5', 'B5', 'G4', 'A5', 'G5', 'E4', 'F#5', 'A5', 'F#4', 'G5', 'F#5', 'A4', 'E5', 'D5', '2.6', 'A3', 'F#3' ...
#        list(['7.9.1', '9', '7.9.1', '9', '7.9.1', '9', '11', '4.7.9', '1', '2.6.9', '9.2', '2.6.9', '9.2', '2.6.9', '9.2', 'F#4', '7.9', '2', 'F#4', 'E4', 'A3', '6', 'F#4', 'E4', 'D4', '4.9', '9.1', '4.9', '9.1', '4.9', '9.1', 'A4', 'B4', 'E4', '1', 'C#5', 'B4', 'A4', '11.4', '1', 'C#5', '11.2.6', '6.11', '11.2.6', '6.11', '11.2.6', '6.11', '2.8', '4', '2.8', '4', '2.4.8', '4', '4', '2.8', '4', '9.1', '9', '9.1', '4.9', '9.1', '4.9', 'A5', 'F#4', 'B-5', 'D4', 'B5', 'G4', 'B-5', 'B5', 'E6', 'B4', 'E-6', 'E6', 'G6', 'E5', 'G6', 'C#4', 'F#6', 'E6', 'C#5', 'D6', 'C#6', 'G4', 'B5', 'A5', 'F#4', 'G#5', 'A5', 'D6', 'A4', 'C#6', 'D6', 'F#6', 'D5', 'F#6', 'B3', 'E6', 'D6', 'B4', 'C#6', 'B5', 'F#4', 'A5', 'G5', 'E4', 'F#5', 'G5', 'C#6', 'G4', 'C6', 'C#6', 'E6', 'C#5', 'E6', 'E3', 'D6', 'C#6', 'E4', 'D6', 'C#6', 'F4', 'B5', '6.10', '1.6', '6.10', '1.6', '6.10', '1.6', 'B-5', '6.11', '1.6', 'B-5', '6.11', '1.6', 'B-5', '5.8', '11.1', '5.8', '11.1', '5.8', '11.1', 'G#5', '5.10', '11.1', 'G#5', '5.10', '11.1', 'G#5', 'F#5', '6.10', 'F#5', '6.10', 'F#5', '6.10', '7.9.1', '9', '7.9.1', '9', '7.9.1', '9', '9', '1.7', '9', '2.6', '11', '11.2.6', '11', '11.2.6', '11', 'D4', '2.6', '11', 'E4', '6', '11', 'D4', '4.7.9', '9.1', '4.7.9', '9.1', '4.7.9', '9.1', '4.7.9', '4.7.9', '1', '4.7.9', '4.7.11', '1', '1.4.7', '2.6.9', '0', '2.7', '11', '2.7', '11', '2.8', '10', '2.8', '10', '2.4.8', '10', '10', '2.8', '10', '9.1', '9', '9.1', '4.9', '9.1', '4.9', 'E5', 'C#4', 'F5', 'A3', 'F#5', 'D4', 'F5', 'F#5', 'B5', 'F#4', 'B-5', 'B5', 'D6', 'B4', 'D6', 'G#3', 'C#6', 'B5', 'G#4', 'C#6', 'B5', 'A5', 'G#5', 'D4', 'A5', 'G#5', 'F#5', 'E5', 'C#4', 'E-5', 'E5', 'A5', 'E4', 'G#5', 'A5', 'C#6', 'A4', 'C#6', 'F#3', 'B5', 'A5', 'F#4', 'B5', 'A5', 'G#5', 'F#5', 'C#4', 'G#5', 'F#5', 'E5', 'D5', 'B3', 'C#5', 'D5', 'G#5', 'D4', 'G5', 'G#5', 'B5', 'G#4', 'B5', 'B2', 'A5', 'G#5', 'B3', 'A5', 'G#5', 'C4', 'F#5', '1.5', '8.1', 'C#5', 'F5', '8.1', 'C#5', 'F5', '8.1', 'F5', '1.6', '8.1', 'F5', '1.6', '8.1', 'F5', '2.4.8', '4.8.11', '2.4.8', '4.8.11', '2.4.8', '4.8.11', 'E5', 'G#4', '2.6', '4.9', 'E5', 'G#4', '2.6', '4.9', 'G#5', 'B4', '9.1', '4.9', '9.1', '4.9', '9.1', '4.9', 'A3', 'A2', 'A3', 'A2', 'A3', 'A2', 'G3', 'G2', 'A3', 'A2', '1.4.7.10', '10', '1.4.7.10', '10', '1.4.7.10', '10', 'A4', 'A3', 'A4', 'A3', 'A4', 'A3', 'G4', 'G3', 'A4', 'A3', '10.2.5', '5.10', '10.2.5', '5.10', '10.2.5', '5.10', '2.5', '2.5', '2.5', '2.5', '2.5', '2.5', '1.4', '1.4', '2.5', '2.5', '10.2', '10.2', '10.2', '10.2', '9.1', '9.1', '10.2', '10.2', '7.10', '7.10', '7.10', '7.10', '6.9', '6.9', '7.10', '7.10', '3.7', '3.7', '2', '0.3.7', '0', '0.3.7', '0', '2.5', '5', '5', '10.2', '10', '10.2', '5.10', '10.2', '5.10', '2.5', '2.5', '2.5', '1.4', '2.5', '10.2', 'B-2', 'F3', '10.2', '10.2', '10.2', 'B-2', '10.2', '10.2', 'F3', '10.2', '9.1', '10.2', '10.2', '2.5', 'A2', 'F3', '0.3', '0.3', '0.3', 'A2', '0.3.5', '0.3.5', 'F3', '0.3.5', '0.3', '0.3.5', '5.9.0', 'F2', 'F3', '5.9.0', '0.3', '5.9.0', 'F2', '5.9.0', '5.9.0', 'F3', '5.9.0', '5.8.11', '0.3', '5.9.0', 'B-2', 'F3', '10.2.5', '10.2', '10.2.5', 'B-2', '10.2.5', '10.2.5', 'F3', '10.2.5', '10.2', '10.2.5', '7.10.2', 'G2', 'G3', '7.10.2', '10.2', '7.10.2', 'G2', '7.10.2', '7.10.2', 'G3', '10.2', '10.2', '7.10.2', '10.2.5', 'B-2', 'F3', '10.2.5', '10.2', '10.2.5', 'B-2', '10.2.5', '10.2.5', 'F3', '10.2.5', '3.7.10', '10.2', '10.2.5', '5.9.0', 'F2', 'F3', '0.3', 'F2', '0.3.5', '0.3.5', 'F3', '0.3.5', '0.3', '5.9.0', '10.2.5', 'B-2', 'D3', '10.2.5', '5.10', '10.2.5', 'F2', '0.3.5', '0.3.5', 'E-3', '0.3.5', '10.2.5', '5.9', '5.9.0', '10.2.5', 'B-2', 'D3', '10.2.5', '5.10', '10.2.5', 'F2', '0.3.5', '0.3.5', 'E-3', '0.3.5', '10.2.5', '5.9', '5.9.0', '10.2.5', 'B-2', 'B-2', 'B-1', 'B-2', 'B-1', 'B-2', 'B-1', 'B-2', 'B-1', 'C3', 'C2', 'D3', 'D2', '2', 'D2', '2', 'D2', '2', 'D2', '2', 'D2', '4', 'E2', '5', 'F2', 'F3', 'F2', 'F3', 'F2', 'F3', 'F2', 'F3', 'F2', 'G3', 'G2', 'A3', 'A2', '9', '9', '9', '9', '11', '11', '1', '1', '2', '2', '9.1.4', '9.1.4', '9. ...
#        list(['5.8.0', 'C3', 'F2', 'G#3', 'C5', 'B-4', 'G#4', 'B-4', 'G4', '4.7', 'G#4', 'F4', 'F3', 'G#2', 'F2', 'F#4', 'E-4', 'A2', 'F4', 'C#4', 'G2', 'E-4', 'C4', 'A2', 'C#4', 'B-3', 'C4', 'G#3', 'B-3', 'F#3', 'C#3', 'F3', 'G#3', 'F3', 'C3', 'G3', 'E3', '10.1', '7.10.1', '8.0', '7.10', '1.4.7.10', 'C#5', 'C5', 'C5', 'F5', '5.8', 'G4', 'B-4', 'C#5', 'B-4', 'G4', 'F4', '7.10.1', 'E4', 'C3', 'F3', 'F#5', 'G#3', 'G5', 'G#5', 'C4', 'A5', 'B-3', 'B-5', 'G#3', 'B5', '5.8.0', 'G3', 'C6', 'B-5', 'G#5', 'C3', 'G#3', 'F2', '8.10', '7.8', 'B-5', 'G5', '7.8', '5.7', 'G#5', 'F5', '5.7', 'F#5', 'E-5', '4.7', '3.5', 'F5', 'C#5', 'F3', 'G#2', 'F2', '1.3', '0.1', 'E-5', 'C5', 'A2', '0.1', 'C#5', 'B-4', 'G2', 'C#5', 'B-4', 'C#5', 'G#4', 'A2', 'C#5', 'G#4', 'C#5', 'F#4', 'C#5', 'F#4', 'C#3', 'F3', 'C#5', 'F4', '1.5', 'C#5', 'F4', '0.3', 'C#5', 'E4', '0.3', '10.1', '7.10.1', '10.1', '8.0', '8.0', '7.10', 'C#5', '1.4.7.10', 'C5', 'C5', 'G#5', 'G5', 'F5', 'C5', 'G#4', 'G4', 'E-5', '5.8', 'C5', 'C#5', 'B-4', 'G4', 'F4', 'C4', '7.10.1', 'F4', 'G#4', 'F4', 'C#5', 'C5', '5.8.0', '0.4.7', 'G#3', 'F3', '5.8.0', 'C#4', 'G#4', 'C4', 'C5', 'G#4', 'C5', 'G#4', '0', 'C5', 'G4', 'B4', 'G#4', '5', 'C5', 'G#4', 'C5', 'G#4', '5', 'C5', 'A4', 'E-5', 'B-4', 'C#5', 'B-4', 'C#5', 'B-4', '5', 'C#5', 'C#5', 'F5', 'B-4', 'C#5', 'G#4', 'C#5', 'G4', '5', 'C#5', 'G#4', 'C#5', 'G#4', 'C5', 'G#4', 'C5', 'G#4', '5', 'C5', 'G#4', 'C5', 'F#4', 'B-4', 'F#4', 'B-4', 'F#4', '5', 'B-4', 'F#4', 'B-4', 'F4', 'B-2', 'G#4', 'F4', 'G#4', 'F4', '6.10', 'G#4', 'F4', 'G#4', 'E4', 'C3', 'G4', 'E4', 'G4', 'E4', '5.8', 'G4', 'F4', 'G#4', 'C3', 'C5', 'G#4', 'C5', 'G#4', '4.7', 'C5', 'G4', 'B4', 'G#4', 'F2', 'C5', 'G#4', 'C5', 'G#4', '5', 'C5', 'A4', 'E-5', 'B-4', 'C#5', 'B-4', 'C#5', 'B-4', '5', 'C#5', 'C#5', 'F5', 'B-4', 'C#5', 'G#4', 'C#5', 'G4', '5.10', 'C#5', 'G#4', 'C#5', 'G#4', 'C5', 'G#4', 'C5', 'G#4', '3', 'C5', 'C5', 'E-5', 'F4', 'B-4', 'C#5', 'F5', 'E-5', '3.8', 'C#5', 'B-4', 'C#5', 'E-4', 'C#3', 'G#4', 'C5', 'E-5', 'C#5', '1.5', 'C5', 'A4', 'C5', 'E-4', 'E-3', 'G4', 'B-4', 'C#5', 'C5', '0.3', 'B-4', 'G#4', 'G#4', 'E-3', 'C5', 'G#4', 'C5', 'G#4', '1.7', 'C5', 'B4', 'D5', 'C5', '8.0', 'E-5', 'C5', 'E-4', 'E-5', 'C5', 'E-4', 'E-5', 'C5', 'E-4', 'E-5', 'C#5', 'E4', 'E5', 'G5', 'E-4', 'B-5', 'C5', 'E-4', 'E-5', 'C#5', 'E-4', 'E5', 'G5', 'E-3', 'B-5', 'G#5', 'E-4', 'G5', 'F5', 'E-4', 'G5', 'G#5', 'E-4', 'G#4', 'E-3', 'C5', 'G#4', 'E-4', 'C5', 'G#4', 'E-4', 'C5', 'B4', '1.3', 'D5', 'C5', '8.0.3', 'E-5', 'C5', 'E-4', 'E-5', 'C5', 'E-4', 'E-5', 'D5', 'E-4', 'F5', 'E-5', 'E4', 'F#5', 'A5', 'E-4', 'C6', 'D5', 'E-4', 'F5', 'E-5', 'F#4', 'F#5', 'A5', 'F3', 'C6', 'B-5', 'F4', 'A5', 'G5', 'F4', 'A5', 'B-5', 'F4', 'C#5', 'F3', 'F5', 'C#5', 'F4', 'F5', 'C#5', 'F4', 'F5', 'C5', '3.5', 'E5', 'C#5', '10.1.5', 'F5', 'C#5', 'F4', 'F5', 'C#5', 'F4', 'F5', 'B-5', 'F4', 'C#5', 'E5', 'F#4', 'C#5', 'E-5', 'F4', 'C#5', 'E5', 'F4', 'C#5', 'G#5', 'F4', 'C5', 'F5', 'G3', 'C5', 'E-5', 'C#4', 'E4', 'C5', 'G#5', 'E-4', 'C5', '10.1', 'E4', 'C#5', 'E5', 'G#3', 'C#5', 'E-5', 'F4', 'C4', 'C#5', 'E5', 'E-4', 'C#5', '8.0', 'G#4', 'C5', 'F5', 'G3', 'C5', 'E-5', 'C#4', 'E4', 'C5', 'G#5', 'E-4', 'C5', 'C6', 'E4', 'E-6', 'F5', 'G#3', 'B-5', 'C#6', 'F4', 'C4', 'F6', 'E-6', 'E-4', 'C#6', 'B-5', 'G#4', 'C#6', 'E-5', 'C#3', 'G#5', 'C6', '1.5', 'E-6', 'C#6', 'C6', 'A5', '1.5', 'C6', 'E-5', 'E-3', 'G5', 'B-5', '0.3', 'C#6', 'C6', 'B-5', 'G#5', '0.3', 'G5', 'F5', 'E-3', 'E5', 'E-5', '1.3', 'G3', 'C#5', 'C5', 'B-4', 'G#4', 'G#3', 'G#3', 'B-3', 'G#3', 'G#3', 'G3', '1.3', 'G#3', '8.0.3', 'G#3', 'G#2', 'G#3', 'G#2', 'A3', 'G#2', 'G2', '10.0', 'B-3', 'G#2', 'G#2', '0.1', 'E-4', 'G#2', 'G4', 'A2', 'B-4', 'E-5', 'G5', '10.0', 'B-5', 'B-2', 'E-6', 'G#5', '0.1', 'G#3', 'E-3', 'G#3', '10.1.3', 'G#3', '10.1.3', 'G3', '10.1.3', 'G#3', '8.0', 'G#3', 'G#2', 'G#3', 'G#2', 'A3', 'G#2', 'G2', '10.0', 'B-3', 'G#2', 'G#2', '0.1', 'E-4', 'G#2', 'E4', 'A2', 'G4', 'C5', 'E5', '10.0', 'G5', 'B-2', 'C6', 'F5', '0.1', '5.8', 'E-3', '5.8', '7.10.0', '5.8',  ...
#        list(['1.4.8', '1.4.8', '1.4.8', '1.4.8', '1.4.8', '1.4.8', '3.6', '8', '8.0.3', '9', '8', '1.4.8', '1.4.8', '6.9.1', '6.9.1', '8.0.3', '8.0.3', '1.4.8', '1.4.8', '1.4.8', '1.4.8', '1.4.8', '1.4.8', '6', '6.9.1', '1.6', '9', '1.4.8', '8', '8', '4.8', 'C#4', '1.4.8', 'E-4', 'E4', 'F#4', 'A4', '1.4.8', '1.4.8', '1.4.8', '1.4.8', '1.4.8', '1.4.8', '3.6', '8', '8.0.3', '9', '8', '1.4.8', '1.4.8', '6.9.1', '6.9.1', '8.0.3', '8.0.3', '1.4.8', '1', '1', '1', '9.1', '1.6', '6', 'A4', '9', '4.8.11', '11', '6.11', '8.11', 'E4', '11.4', 'F#4', 'G#4', 'A4', 'C#5', 'B4', 'E4', 'E3', 'G#3', 'F#4', 'A3', 'E4', 'G#3', 'F#4', 'A3', 'G#4', 'B4', 'B3', 'F#4', 'A3', 'B4', 'G#4', 'B3', 'E4', 'G#3', 'E-4', 'B4', 'B2', 'F#3', 'E4', 'G#3', 'E-4', 'F#3', '1.4', 'G#3', 'B4', 'F#4', 'A3', 'F4', 'G#3', 'F#4', 'A3', 'E-4', 'F#3', 'E4', 'B4', 'G#3', 'E3', 'F#4', 'A3', 'E4', 'G#3', 'F#4', 'A3', '8.1', 'B3', '11.4', 'G#3', '8.11', 'E3', 'E4', 'G#3', 'F#4', 'E-4', 'B3', 'B2', 'E4', 'C#4', 'E-4', 'B3', 'C#4', 'F#3', 'B3', 'E-3', 'B-3', 'D3', 'G4', 'B3', 'E-3', 'E-4', 'A3', 'E4', 'G#4', 'G#3', 'E3', 'E-4', 'F#3', 'C#4', 'E3', 'E-4', 'F#3', 'E4', 'G#4', 'G#3', 'E-4', 'G3', 'G#4', 'E4', 'G#3', 'C#4', 'E3', 'E-4', 'G#4', 'G#2', 'F#3', 'C#4', 'E3', 'C4', 'E-3', '9.1', 'E3', 'E-4', 'G#4', 'F#3', 'C#4', 'E3', 'E-4', 'F#3', 'C4', 'E-3', 'C#5', 'C#4', 'C#3', 'A2', 'E-4', 'E4', 'F#4', 'E-3', 'G4', 'E3', 'C5', 'E-5', 'C#5', '8.0', 'G#2', 'E-3', 'C3', 'G#2', 'G4', 'C#5', 'E3', 'A2', 'C5', 'E-5', 'C#5', '8.0', 'G#2', 'E3', 'E-3', 'C3', 'G#2', 'G4', 'C#5', 'E3', 'A2', 'C5', 'E-5', 'C#5', 'C5', '8.0', 'E-3', 'C3', 'G#2', 'G#3', 'F#3', 'A4', 'B4', 'B2', 'E-3', 'E-4', 'A3', 'B4', 'E4', 'G#3', 'E3', 'F#4', 'A3', 'E4', 'G#3', 'F#4', 'A3', 'B4', 'G#4', 'B3', 'F#4', 'A3', 'B4', 'G#4', 'B3', 'E4', 'G#3', 'E-4', 'B4', 'F#3', 'B2', 'E4', 'G#3', 'E-4', 'F#3', '1.4', 'G#3', 'F#4', 'B4', 'A3', 'F4', 'G#3', 'F#4', 'A3', 'E-4', 'F#3', 'B4', 'E4', 'G#3', 'E3', 'F#4', 'A3', 'E4', 'G#3', 'F#4', 'A3', '8.1', 'B3', '11.4', 'G#3', '8.11', 'E3', 'E4', 'G#3', 'E-4', 'F#4', 'B3', 'B2', 'E4', 'C#4', 'E-4', 'B3', 'C#4', 'F#3', 'E-4', 'B3', 'B3', 'E-3', 'G4', 'C#4', 'A2', 'E3', 'E-4', 'E-3', 'G#4', 'C4', 'E-3', 'G#2', 'E-4', 'C3', 'D4', 'B2', 'E-4', 'C3', 'A4', 'E4', 'F#2', 'C#3', 'C#4', 'E3', 'C4', 'A4', 'E-3', 'F#2', 'C#4', 'E3', 'G#4', 'C4', 'G#2', 'E-3', 'E-4', 'C3', 'D4', 'B2', 'E-4', 'C3', 'E4', 'A4', 'F#2', 'C#3', 'C#4', 'E3', 'C4', 'A4', 'F#2', 'E-3', 'C#4', 'E3', 'G#4', 'C4', '3.8', 'E-5', '4.8', 'C#5', 'G#3', 'E-5', '3.6', 'C5', 'C#5', '1.4', 'A4', 'B4', 'G#4', '0.3', 'A4', 'F#4', '9.1', 'G#2', 'G#4', '8.1', 'E4', 'F#4', '0.6', 'E-4', 'E4', '1.4.8', 'C#2', 'C2', 'C#2', 'C2', 'C#2', 'C2', 'C#2', 'C2', '1.4.8', 'C#2', 'C2', 'C#2', 'C2', '1.4.8', 'C#2', 'C2', 'C#2', 'C2', '1.4.8', 'C#2', 'C2', 'C#2', 'C2', 'C#2', 'C2', 'C#2', 'C2', 'C#2', 'C2', 'C#2', 'C2', 'C#2', 'C2', 'C#2', 'B1', '9.1.4', 'A1', 'G#1', 'A1', 'G#1', 'A1', 'G#1', 'A1', 'G#1', '9.1.4', 'A1', 'G#1', 'A1', 'G#1', '9.1.4', 'A1', 'G#1', 'A1', 'G#1', '9.1.4', 'A1', 'G#1', 'A1', 'G#1', 'A1', 'G#1', 'A1', 'G#1', 'A1', 'G#1', 'A1', 'G#1', 'A1', 'G#1', 'A1', 'G#1', '2.6.9', 'F1', 'F1', 'F1', 'F1', '2.6.9', 'F1', 'F1', '2.6.9', 'F1', 'F1', '2.6.9', 'F1', 'G#1', 'A1', 'G#1', 'A1', 'C#2', 'D2', 'C#2', 'D2', 'F2', 'F#2', 'F2', 'F#2', 'A2', 'G#2', 'G2', 'G#2', 'G2', 'G#2', 'G2', 'G#2', 'F#2', '1.4.8', 'E2', 'E-2', 'E2', 'E-2', 'E2', 'E-2', 'E2', 'E-2', '1.4.8', 'C#2', 'C2', 'C#2', 'C2', 'C#2', 'C2', 'C#2', 'B1', 'A1', 'G#1', 'A1', 'G#1', 'A1', 'C#2', 'E-2', 'A2', '8.0.3', '8', '8.0.3', '8', '4', '1.4.8', '1.4', '8', '9', '8', '8', '8.0.3', '8.0', '8', '8', '6', '8.0.3', '8.0.3', '8', '8', '4', '1.4.8', '1.4.8', '1.4', '8', '8', '9', '8', '8', '8', '8.0.3', '8.0.3', '8.0', '8', '8', '6', '6', '3', '3', '0', '3.6.9', '3.6.9', '0', '8', '0.3.6', '0.3.6', '8', '9', '0.3.6', '0.3.6', '9', '9', '1.4.7', '1.4.7', '9', '9', '9', '8.0.3', '8', '8', '8', '6', '6', '3', '3', '0', '3.6.9', '3.6.9', '0', '8', '0.3.6', '0.3.6', '8', '9', '0.3.6', ' ...
#        list(['A4', 'A3', 'E5', 'E4', 'E-5', 'E-4', 'E5', 'E4', 'C5', 'C4', 'B4', 'B3', 'A4', 'A3', '4.8.11', 'E3', 'C4', 'C3', 'A3', 'A2', 'A3', 'A2', '5.9', 'D2', '7.10', 'C#2', '5.9', 'D2', 'A3', 'A2', 'B3', 'B2', 'C4', 'C3', '4.8.11', 'E2', '0', 'C2', '9', 'A1', '2.5.9', 'A1', '9.0.4', 'A1', 'A3', 'A3', '2.5.9', 'D4', 'E4', 'A1', 'F4', 'E4', '9.0.4', 'A3', 'A1', 'G4', 'F4', '2.5.9', 'A3', 'A1', 'F4', 'E4', '9.0.4', 'A3', 'A1', 'A3', 'A4', 'A4', '2.5.9', '2', '4', 'A2', '5', '4', '9.0.4', '9', 'A2', '4', '4', '4.7.11', '7', '9', 'G2', '11', '11', '3.6', '11', '11.3', '7', '7', '4', '4', '11', '3.6', '11', '11.3', '7', '7', '4', '4', '7', 'E2', '4', 'F2', 'E2', 'F2', 'E2', 'F2', 'E2', 'F2', '5', 'E2', 'F2', 'E2', 'F2', 'E2', 'F2', 'E2', 'F2', '2', 'E2', 'F2', 'E2', 'F2', 'E2', 'F2', 'E2', 'F2', '4', 'E2', 'F2', 'E2', 'F2', 'E2', 'F2', 'E2', 'F2', '0', 'E2', 'F2', 'E2', 'F2', 'E2', 'F2', 'E2', 'F2', '2', 'E2', 'F2', 'E2', 'F2', 'E2', 'F2', 'E2', 'F2', '11', 'E2', 'F2', 'E2', 'F2', 'E2', 'F2', 'E2', 'G#2', '9', '9', '4', '4', '3', '3', '4', '4', '0.4', '4', '11.4', '2', '4.9', '0', '2.7', '11', '0.5', '9', '11.4', '8', '0.5', '9', '11.4', '7', '9.2', '5', '1.7', '4', '9.2', '5', '11.4', '8', '0.5', '9', '2.8', '11', '4.9', '0', '11.4', '2', '4.9', '0', 'A3', 'A2', '5.9', '9.2', '7.10', 'C#2', 'A2', '5.9', 'D2', '5.9', '9', '4.9', '7', '9.2', '5', '7.0', '4', '5.10', '2', '4.9', '1', '5.10', '2', '4.9', '0', '2.7', '10', '0.6', '9', '2.7', '10', '4.9', '1', '5.10', '2', '1.7', '4', '9.2', '5', '4.9', '7', '9.2', '5', '7.10.2', '2', '2.5.9', '2', 'D4', 'D5', 'D5', '7.10.2', '7', '9', '2', '10', '9', '2.5.9', '2', '2', '0', '10', '7.10.2', '2', '2', '10', '9', '2.5.9', '2', '2', '2', '2', '7.10.2', '7', '9', '2', '10', '9', '2.5.9', '2', '2', '9', '9', '9.0.4', '0', '2', '0', '4', '4', '8.11', '4', '4.8', '0', '0', '9', '9', '4', '8.11', '4', '4.8', '0', '0', '9', '9', '10', '10', '7', '7', '10', '10', '7', '7', '10', '10', '7', '7', '10', '10', '7', '7', 'B3', 'B1', 'B4', 'B2', 'B3', 'B1', 'B4', 'B2', 'B3', 'B1', 'B4', 'B2', 'B3', 'B1', 'B4', 'B2', 'B3', 'B1', 'B4', 'B2', 'B3', 'B1', 'B4', 'B2', 'B3', 'B1', 'B4', 'B2', 'B3', 'B1', 'B4', 'B2', 'G#3', 'G#1', 'G#4', 'G#2', 'G#3', 'G#1', 'G#4', 'G#2', 'G#3', 'G#1', 'G#4', 'G#2', 'G#3', 'G#1', 'G#4', 'G#2', 'G#3', 'G#1', 'G#4', 'G#2', 'G#3', 'G#1', 'G#4', 'G#2', 'G#3', 'G#1', 'G#4', 'G#2', 'G#3', 'G#1', 'G#4', 'G#2', '11', '11', '8', '8', '11', '11', '4', '4', '11', '11', '8', '8', '4', '4', '11', '11', '4.8', '11', '11', 'B3', 'B1', 'B4', 'B2', 'B3', 'B1', 'B4', 'B2', 'G#3', 'G#1', 'G#4', 'G#2', 'G#3', 'G#1', 'G#4', 'G#2', 'B3', 'B1', 'B4', 'B2', 'B3', 'B1', 'B4', 'B2', 'E4', 'E2', 'E5', 'E3', 'E4', 'E2', 'E5', 'E3', 'G#4', 'G#2', 'G#5', 'G#3', 'G#4', 'G#2', 'G#5', 'G#3', 'B4', 'B2', 'B5', 'B3', 'B4', 'B2', 'B5', 'B3', 'E5', 'E3', 'E6', 'E4', 'E5', 'E3', 'E6', 'E4', 'B4', 'B2', 'B5', 'B3', 'B4', 'B2', 'B5', 'B3', '4.8', '11', '11', '4.8', '11.4', '4.8', '11.4', '4.8', '11.4', '8', '11.4', '6.8', '11.4', '8', '11.4', '9.1', '1.4', '9.1', '1.4', '9.1', '1.4', '3.4', '1.4', '3.4', '8.11', '4', '4.8', '11.4', '4.8', '11.4', '8', '11.4', '6.8', '11.4', '8', '11.4', '4.9', '1.4', '4.9', '1.4', '9.1', 'E2', 'C#3', 'E3', 'C#4', '9.1', 'A3', 'C#4', '4.8', '11.4', '4.8', '11.4', '3.6.9', '11.4', '3.6.9', '11.4', '6.11', '3.4', '4.9', '1.4', '4.8', '11.4', '4.8', '11.4', '3.6.9', '11.4', '3.6.9', '11.4', '6.11', '3.4', '4.9', '1.4', '4.8', '11.4', '4.8', '11.4', 'E4', '4.8', '4.8', '11.4', '4.6', '4.9', '4.8', '11.4', '11.4', '1.4', '4.10', '1.4', '11.4', '0.4', '4.9', '0.4', '4.9', '11.4', '4.8', '11.4', '4.9', '11.4', '4.7', '11.4', '9', '9', '4.8.11', '4.8.11', '4.9', '1.4', '4.8.11', '4.8.11', '11.4', '11.3', '4.8', '11.4', '4.8', '11.4', '9', '9', '4.8.11', '4.8.11', '4.9', '1.4', '4.8.11', '4.8.11', '11.4', '11.3', '4', 'E2', '4', 'E2', '8.11', '11.4', '8', '11.4', '6.8', '11.4', '8', '11.4', '0.4', '0.4', '8.11', '3.4', '3.4', '4', '4', '4', '4', '8.11', '11.4', '8', '11.4', '6.8', '11.4 ...
#        list(['9.0', '0.5', 'F4', 'F3', 'A4', 'A3', '2', '0', 'G4', '0.4.7', '10', '7', '9', '5.9', '9.2', '7.10.0', '0.4', '5.9.0', '0.5', 'C4', 'C3', '0.1', '0.1', 'B3', 'B2', '0.1', '0.1', 'C4', 'C3', '9.0', '0.5', 'F4', 'F3', 'A4', 'A3', '9.2', '2.5.9', '9.2', '2.5.9', '5', '9', '10.1', '4.7.9', '10.1', '4.7.9', '9.0', '5.9', '7.10', 'C5', 'E4', 'C4', '5.9', 'C5', '5', 'C4', 'C4', 'C3', '0.1', '0.1', 'B3', 'B2', '0.1', '0.1', 'C4', 'C3', 'G3', 'C4', '0.4', 'E4', 'E3', 'G4', 'G3', '10.1', '1.4.7', '10.2', 'F2', 'D3', 'F4', 'F3', 'B-4', 'B-3', '10.2.5', '10.2', '3.6', 'D3', '9.0', '2.5', 'B-3', '0.5', '9', '1.4', '7.10', 'A2', '0.5', 'A3', '5.9', '0.5', '0', 'G4', '0.4.7', '10', '7', '9', '5.9', '9.2', '4.7.10', 'C2', 'C3', '5.9', 'F2', 'C3', 'C4', 'C3', '0.1', '0.1', 'B3', 'B2', '0.1', '0.1', 'C4', 'C3', '0', 'G5', '0.4.7', '10', '7', '9', '5.9', '9.2', '4.7', '10.0', 'C4', '5', '5.9', 'C4', 'C5', 'C4', '0.1', '0.1', 'B4', 'B3', '0.1', '0.1', 'C5', 'C4', 'F4', 'F3', 'E4', 'E3', 'F4', 'F3', '1.3', '1.3', 'C4', 'C3', '1.3', '1.3', 'C#4', 'C#3', '10.0', '10.0', 'A3', 'A2', '10.0', '10.0', 'B-3', 'B-2', '6.8', '6.8', '1.5.8', '1.5.8', '1.5.8', 'C#2', '1.5.8', '1.5.8', '1.5.8', '1.5.8', '1.5.8', '3.8', 'C#5', 'G#1', 'E-2', 'E-2', 'C5', 'E-2', 'G#2', 'G#2', '10.1.5', 'B-2', '10.1.5', '10.1.5', '10.1.5', '10.1.5', '10.1.5', 'B-4', '0.5', 'F1', 'C2', 'C2', 'G#4', 'C2', 'F2', 'F2', '6.10.1', 'F#2', '6.10.1', '6.10.1', '6.10.1', '6.10.1', '6.10.1', '6.10.1', '6.8', '6.8', '6.10.1', '6.8', '6.10.1', '6.8', '6.10.1', '6.8', '6.8', '6.10.1', '6.8', '6.10.1', '6.8', '6.10.1', '6.8', '6.8', '6.10.1', '6.8', '6.10.1', '6.8', '6.10.1', '6.8', '6.8', '6.10.1', '6.8', '6.10.1', '6.8', '8.1', '6', '5', '5', '6', '6.10.1', '6.10.1', '8.1', '6', '5', '5', '6', '6.10.1', '6.10.1', '4.10', '8', '7', '7', '10.2', '7', '10.3', '10.3', '4.10', '8', '7', '7', '10.2', '7', '10.3', '10.3', '4.10', '7', '7', '7', '4.10', '7', '7', '7', '4.10', '7', '7', '7', '4.10', '7', '7', '7', '7', '7', '7', '7', '7', '7', '7', '7', '7', '7', '7', '7', '7.11.2', '7', 'G5', 'G5', 'G4', 'G5', 'G5', 'G4', 'G5', 'G5', 'G4', 'G5', 'G5', 'G4', '2.5', 'G5', 'G5', 'G4', 'G5', 'G5', 'G4', '0.4', 'G5', 'G5', 'G4', '2.7', 'G5', 'G5', 'E5', '0.4.7', 'G5', 'G5', 'G5', 'C6', 'C4', 'C6', 'C6', 'E4', 'E6', 'E6', 'E6', 'A4', 'A6', 'A6', '7.11', 'A6', 'G4', '7.11', 'G6', 'G6', 'G6', 'F6', 'F4', 'F6', 'F6', 'D4', 'D6', 'D6', 'D6', 'E4', 'E6', 'E6', '9.0.4', 'E5', '9.0.4', 'C6', 'C6', 'D6', 'C6', 'C6', 'B5', 'F6', 'F6', 'G6', 'F6', 'F6', '0.4.7', 'E6', 'C5', 'E5', 'C4', 'G4', 'E-5', '6.9', 'E5', 'G4', 'E5', '0.4.7', 'G5', 'G5', 'G5', 'C6', 'C4', 'C6', 'C6', 'E4', 'E6', 'E6', '9.0', 'E6', 'A6', 'A6', 'E5', '9.0.4', 'A5', 'A5', 'A5', 'C6', 'C4', 'C6', 'C6', 'E4', 'E6', 'E6', 'E6', '11.2.4', '5.8', '11.2.4', '5.8', '11.2.4', '5.8', '11.2.4', 'G5', '0.4', 'F6', 'E6', 'F5', '7.11', 'E6', 'D6', '0.4', 'C4', 'C5', 'E5', 'C4', 'G4', 'E-5', '6.9', 'E5', 'G4', 'G4', '0.4', 'C5', 'C5', 'C5', 'E5', 'E3', 'E5', 'E5', 'G3', 'G5', 'G5', '10.1.4', '10.1', 'G5', 'B-5', '10.1', 'B-4', '2.5', 'D5', 'D5', 'D5', 'F5', 'F3', 'F5', 'F5', 'B-3', 'B-5', 'B-5', 'B-5', '10.2', '2.5', '10.2', '2.5', '10.2', '3.6', '9.0.2', 'F5', '10.2', 'E-6', 'D6', 'F5', '5.9', 'D6', 'C6', '1.4', 'C5', '5.9', 'C#6', 'C6', 'C5', '0.5', 'B-5', 'A5', '0.4', 'D6', 'C4', '0.4', 'C6', 'C6', 'C6', 'B-5', 'B-3', 'B-5', 'B-5', 'G3', 'G5', 'G5', 'G5', 'A3', 'A5', 'A5', '2.5.9', 'A4', '2.5.9', 'F5', 'F5', 'G5', 'F5', 'F5', '0.4.7', 'E5', 'B-5', 'B-5', 'C6', 'B-5', 'B-5', '5.9.0', 'A5', 'A4', 'F4', 'C4', 'F3', '9.10', 'G#4', '11.2', '9.10', 'A4', 'C4', '0.4', 'C5', '0.4', 'C7', 'C7', 'C7', 'B-6', 'B-4', 'B-6', 'B-6', 'G4', 'G6', 'G6', 'G6', 'A4', 'A6', 'A6', '2.5.9', 'A5', '2.5.9', 'F6', 'F6', 'G6', 'F6', 'F6', 'B-5', 'G6', 'G6', 'B-6', 'A6', 'G6', 'F6', '5.9', 'F4', 'A4', 'F3', 'C4', '9.10', 'G#4', '11.2', '9.10', 'A4', 'C4', 'C5', 'C4', '0.1', '0.1', 'B4', 'B3', '0.1', '0.1', 'C5', 'C4', 'B4', 'B3', '0.1', '0.1', 'C5', 'C4', '8.10', '8.10', ...
#        list(['4.8', 'C#2', 'C#3', 'C#4', 'C#5', '4.8', '3.6', '3.6', 'C#2', 'C#3', 'C#4', 'C#5', '3.6', '6.9', 'C#2', 'C#3', 'C#4', 'C#5', '6.9', '4.8', '3.6', '4.8', 'C#2', 'C#3', 'C#4', 'C#5', '4.8', '5.11', 'C#2', 'C#3', 'C#4', 'C#5', '5.11', 'G#4', '6.9', '5.8', '6.9', 'C#2', 'C#3', 'C#4', '6.9.1', '6.9', '6.9', '9.1', 'C#2', 'C#3', 'C#4', 'C#5', '9.1', '6.9', '4.8', 'C#2', 'C#3', 'C#4', 'C#5', '4.8', '9.1.4', '8', '8.0.3', 'G#2', '8.0.3', 'G#3', 'G#5', '8.0', '1.4.7', '8', '8.0.3', 'G#2', '8.0.3', 'G#3', 'G#5', '8.0.3', '4.8', '8', '3.6.9', 'G#2', '3.6.9', 'G#3', 'G#5', '3.6.9', '9.1.4', '8', '8.0.3', 'G#2', '8.0.3', 'G#3', 'G#4', '8.0.3', '8', 'G#2', 'G#3', 'G#4', '4.8.11', '8', 'B2', 'B3', 'E6', '11.4', '9', 'C#5', 'C#3', '9.1.4', 'C#4', 'C#6', '9.1.4', '11', '11.3', 'B2', '11.3.6', 'B3', 'B5', '9.1.4', '4.8.11', 'E2', 'B2', '4.8.11', 'E3', 'E5', '4.8', 'E2', 'B2', 'B3', 'B4', '4.8', '3.6', '3.6', 'E2', 'B2', 'B3', 'B4', '3.6', '9.1', 'E2', 'B2', 'B3', 'B4', '3.9', 'F#4', '4.8', '3.6', '4.8', 'E2', 'B2', 'B3', 'B4', '4.8', '8.11.2', 'E2', 'E3', 'E4', 'E5', '8.11.2', '9.1', '9.1', 'E2', 'E3', 'E4', '9.1.4', '9.1', '9.1', 'E2', 'E3', 'E4', 'E5', '4.8.11', '4.8.11', 'E2', 'E3', 'E4', 'E5', '4.8.11', '4.8.11', '11', '11.3.6', 'B2', '11.3.6', 'B3', 'B5', '11.3.6', '4.8.11', '11', '3.6', 'B2', '11.3.6', 'B3', 'B5', '4.8.11', '1.4.8', '11', '11.3.6', 'B2', '3.6', 'B5', 'B3', 'B4', '3.6', 'B5', 'B1', 'B2', 'B3', 'B4', 'A5', '4.8', 'C#2', 'C#3', 'C#4', 'C#5', '4.8', '3.6.9', '6', 'C#5', 'F#2', '6.9.1', 'F#3', 'A5', 'C#5', 'E4', 'G#4', '8', 'G#2', 'B4', 'G#3', 'G#5', 'C4', '6.9', '1.4.8', 'C#2', 'C#2', '1.4.8', 'C#3', 'C#5', '1.4.8', '1.4.7', '9', 'E-4', 'A4', 'A5', '9', 'E-4', 'A4', 'A5', '0.3.6', '8', 'G#4', '4.8', 'F#4', 'G#4', '1.4.8', 'C#2', 'C#3', 'C#5', '1.4.8', '1.4.7', 'A1', 'E-4', 'A2', 'A4', 'A1', 'E-4', 'A2', 'A4', '0.3.6', 'G#1', 'G#2', 'E4', 'G#3', 'F#4', 'G#4', '1.4.8', 'C#2', 'C#3', 'C#5', 'C#2', '1.4.8', 'C#3', 'C#5', 'G#1', '9.1.4', 'A1', 'A2', 'A2', 'A2', '9.1', 'A1', 'A2', 'A2', 'A2', 'A1', 'A2', 'A2', 'A2', '9.1.4', 'A1', 'A2', 'A2', 'A2', '9.1', 'A2', 'A2', 'A2', 'A2', 'A1', 'A2', '9.1.4', 'A2', 'A2', '2.6.9', 'A1', 'A2', 'A2', '9.1.4', 'A2', 'A2', 'A2', '2.6.9', 'A1', 'A2', '9.1.4', 'A1', 'A2', '9.1.4', 'C#2', 'C#3', '4.8.11', 'E2', 'E2', 'E2', 'E2', 'E2', 'E2', 'D2', 'D2', '1.4.8', 'C#2', 'C#2', '2.4.8', 'B1', 'B1', '9.1.4', 'A1', 'A2', 'A2', 'A2', '9.1', 'A1', 'A2', 'A2', 'A2', 'A1', 'A2', 'A2', 'A2', '9.1.4', 'A1', 'A2', 'A2', 'A2', '9.1', 'A2', 'A2', 'A1', 'A2', 'G1', 'G2', 'F#2', '11.2.6', 'B1', 'B2', 'B2', 'C#3', 'D3', 'B2', '2.6', 'B1', 'G#3', 'B2', '9.1.4', 'C#2', 'C#3', 'E2', 'E3', '8.11.2', 'E3', 'E2', 'G#2', 'E2', '9.1', 'A2', 'C#2', 'D2', 'E2', 'F#2', 'E2', 'F#2', 'G#2', 'A4', 'A2', '1.4', '1.4', '1.4', 'A3', 'A4', 'A2', '1.4', '1.4', '1.4', 'A3', 'B4', 'A2', '4.8', '4.8', '2.4', 'B3', 'C#5', 'A2', '4.9', '4.9', 'E3', '11.2', 'A4', 'A2', '1.4', '1.4', '1.4', 'A3', 'A2', '1.4', '1.4', '1.4', '4.9', 'A4', 'D5', 'A2', '6.9', '6.9', '6.9', '1.4', '11.2', 'A2', 'A4', '2.6', '6.9', 'A4', '9.1', '4.9', 'E4', '4.9', '9.1', 'C#4', 'G#4', 'E2', '11.4', '11.4', 'E3', '4.8', 'E2', '8.11', '6.8', '2.4', 'B3', '4.8', '1.4', 'C#4', '4.8', '11.4', 'D4', 'A4', 'A2', '1.4', '1.4', '1.4', 'A3', 'A4', 'A2', '1.4', '1.4', '1.4', 'A3', 'B4', 'A2', '4.8', '4.8', '2.4', 'B3', 'C#5', 'A2', '4.9', '4.9', 'E3', '11.2', 'A4', 'A2', '1.4', '1.4', '9.1.4', 'A3', '1.4.7', '1.4', '6.10', '1.6', '1.6', 'E4', 'D5', 'B2', '6.11', '6.11', 'F#3', '1.4', 'B-3', '11.2', 'B3', 'F#4', '2.6', '6.11', 'G#4', 'G#3', '9.1', '9.1', 'E4', '11.4', '4.8', 'D4', 'B4', 'A2', '4.8', '4.8', '4.8', 'D4', '9.1', '4.9', 'A2', 'B2', 'C#3', 'B2', 'A2', 'G#2', 'F#2', '8.11', 'E2', 'E3', 'E3', 'E3', '8.11', 'E2', 'E3', 'E3', 'E3', '10.1.4', 'C#2', 'C#3', 'C#3', 'C#3', 'F#3', '11.2', 'B1', 'B2', 'B2', '1.4', 'B2', '2.6', 'B1', 'B2', 'B2', 'B2', 'F#3', 'B1', 'B2', 'B1', 'B2', '2.6.9', 'A1', 'A2', 'A2', '7.11.2', 'G2', '9.2', 'F#2', '7.11.2', 'G1', 'G2', '2 ...
# ...
#        list(['B-5', 'G5', 'E-3', 'B-5', 'G#5', 'G5', 'B-3', 'F5', 'E-5', 'D5', 'C5', 'B-4', 'G#4', 'F3', 'G4', 'F4', 'E-4', 'B-3', 'D4', 'C4', 'B-3', 'C4', 'D4', 'E-4', 'G3', 'D4', 'E-4', 'E4', 'B-3', 'E-4', 'E4', 'F4', 'E4', 'F4', 'F#4', 'D3', 'F4', 'F#4', 'G4', 'B-3', 'F#4', 'G4', 'G#4', 'G4', 'G#4', 'G4', 'E-3', 'B-4', 'G#4', 'G4', 'B-3', 'G#4', 'B-4', 'C5', 'D5', 'E-5', 'F5', 'G#2', 'C6', 'B-5', 'G#5', '8.0', 'G5', 'F5', 'E-5', 'D5', 'C5', 'B-4', 'B-2', 'F5', 'E-5', 'D5', 'C5', 'B-4', 'G#4', 'G4', 'F4', 'E-4', 'E-3', 'F4', 'G4', 'G#4', '3.7.10', 'B-4', 'C5', 'D5', 'E-5', 'F5', 'G5', 'E-3', 'B-5', 'G#5', 'G5', 'B-3', 'F5', 'E-5', 'D5', 'C5', 'B-4', 'G#4', 'F3', 'G4', 'F4', 'E-4', 'B-3', 'D4', 'C4', 'B-3', 'C4', 'D4', 'E-4', 'G3', 'D4', 'E-4', 'E4', 'B-3', 'E-4', 'E4', 'F4', 'E4', 'F4', 'F#4', 'D3', 'F4', 'F#4', 'G4', 'B-3', 'F#4', 'G4', 'G#4', 'G4', 'G#4', 'G4', 'E-3', 'B-4', 'G#4', 'G4', 'B-3', 'G#4', 'B-4', 'C5', 'D5', 'E-5', 'F5', 'G#2', 'C6', 'B-5', 'G#5', '8.0', 'G5', 'F5', 'E-5', 'D5', 'C5', 'B-4', 'B-2', 'F5', 'E-5', 'D5', 'E-5', 'F5', 'G5', 'G#5', 'B-5', 'E-5', 'E-3', 'F5', 'G5', 'G#5', '3.7.10', 'B-5', 'C6', 'D6', 'E-6', 'F6', 'G6', 'E-3', 'B-6', 'G#6', 'G6', 'B-3', 'F6', 'E-6', 'D6', 'C6', 'B-5', 'G#5', 'F3', 'G5', 'F5', 'E-5', 'B-3', 'D5', 'C5', 'B-4', 'C5', 'D5', 'E-5', 'G3', 'D5', 'E-5', 'E5', 'B-3', 'E-5', 'E5', 'F5', 'E5', 'F5', 'F#5', 'D3', 'F5', 'F#5', 'G5', 'B-3', 'F#5', 'G5', 'G#5', 'G5', 'G#5', 'G5', 'E-3', 'B-5', 'G#5', 'G5', 'B-3', 'G#5', 'B-5', 'C6', 'D6', 'E-6', 'F6', 'G#2', 'C7', 'B-6', 'G#6', '8.0', 'G6', 'F6', 'E-6', 'D6', 'C6', 'B-5', 'B-2', 'F6', 'E-6', 'D6', 'C6', 'B-5', 'G#5', 'G5', 'F5', 'E-5', 'E-3', 'G5', 'F5', 'E-5', '3.7.10', 'D5', 'C5', 'B-4', 'G#4', 'F4', 'F#4', 'E-2', 'B-4', 'G#4', 'F#4', 'E-3', 'F4', 'E-4', 'C#4', 'B3', 'B-3', 'B3', 'G#2', 'E-4', 'G#4', 'B4', 'G#3', 'E-4', 'G#4', 'F#4', 'E-4', 'F#4', 'F4', 'C#2', 'B4', 'B-4', 'G#4', 'C#3', 'F#4', 'F4', 'E-4', 'C#4', 'B3', 'B-3', 'F#2', 'C#4', 'F#4', 'B-4', 'F#3', 'C#4', 'F#4', 'F4', 'C#4', 'F4', 'E-4', 'B1', 'B-4', 'G#4', 'F#4', 'B2', 'F4', 'E-4', 'C#4', 'B3', 'B-3', 'G#3', 'F2', 'B3', 'F4', 'G#4', 'F3', 'B3', 'F4', 'E-4', 'B3', 'E-4', 'D4', 'B-1', 'G#4', 'F#4', 'F4', 'B-2', 'E-4', 'D4', 'B3', 'B-3', 'G#3', 'F#3', 'E-2', 'B-3', 'E-4', 'F#4', 'E-3', 'B-3', 'E-4', 'C#4', 'B-3', 'C#4', 'B3', 'G#2', 'E-4', 'G#4', 'B4', 'G#3', 'E-4', 'G#4', 'F#4', 'E-4', 'F#4', 'B4', 'B-2', 'F4', 'D4', 'B-4', 'B-3', 'F4', 'D4', 'D5', 'G#4', 'F4', 'E-5', 'E-3', 'B-3', 'F#5', 'F5', 'E-5', 'C#5', 'B4', 'B-4', 'G#4', 'F4', 'F#4', 'F#2', 'B-4', 'G#4', 'F#4', 'C#3', 'F4', 'E-4', 'C#4', 'B3', 'B-3', 'B3', 'G#2', 'D4', 'F4', 'B4', 'D3', 'F4', 'D4', 'F4', 'C#3', 'C#4', 'B3', 'B-3', 'F#2', 'B-4', 'G#4', 'F#4', 'C#3', 'F4', 'E-4', 'C#4', 'B3', 'B-3', 'B3', 'G#2', 'D4', 'F4', 'B4', 'D3', 'F4', 'D4', 'F4', 'C#3', 'C#4', 'B3', 'C#4', 'F#2', 'F#4', 'B-4', 'C#5', 'F#3', 'B-4', 'F#4', 'F4', 'F#4', 'E4', 'E-4', 'B2', 'F#3', 'G#4', 'B4', 'E-5', 'G#3', 'B4', 'G#4', 'G4', 'G#4', 'F#4', 'F4', 'C#3', 'G#3', 'F#4', 'G4', 'G#4', 'B3', 'B-4', 'B4', 'C#5', 'E-5', 'F5', 'F#5', '6.10', 'B-5', 'G#5', 'F#5', 'F5', 'E-5', 'C#5', 'B4', 'B-4', 'G#4', 'B-2', 'B4', 'B-4', 'G#4', '5.8.11', 'F#4', 'F4', 'E-4', 'D4', 'F4', 'G#4', 'B-2', 'B4', 'B-4', 'G#4', '5.8.11', 'F#4', 'F4', 'E-4', 'D4', 'F4', 'G#4', 'B-2', 'B4', 'B-4', 'G#4', '5.8.11', 'F#4', 'F4', 'E-4', 'D4', 'F4', 'G#4', 'B-2', '5.8.11', 'B4', 'D5', 'B4', 'D5', 'F5', 'D5', 'F5', 'F#5', 'G#5', 'B-3', 'B5', 'B-5', 'G#5', '5.8.11', 'F#5', 'F5', 'E-5', 'D5', 'F5', 'G#5', 'B-3', 'B5', 'B-5', 'G#5', 'B4', '5.8', 'F#5', 'F5', 'E-5', 'D5', 'F5', 'G#5', 'B-3', 'B4', '5.8', 'B5', 'G#5', 'B5', 'G#5', 'B5', 'G#5', 'B5', 'G#5', 'B-5', 'B-4', 'B-3', '5.8', 'G#5', 'B-5', 'G#5', 'B-5', 'G#5', 'B-5', 'G#5', 'B-5', 'G5', 'E-3', 'B-5', 'G#5', 'G5', 'B-3', 'F5', 'E-5', 'D5', 'C5', 'B-4', 'G#4', 'F3', 'G4', 'F4', 'E-4', 'B-3', 'D4', 'C4', 'B-3', 'C4', 'D4', 'E-4', 'G3', 'D4', 'E-4', 'E4', 'B-3', 'E-4', 'E4', 'F4', 'E4', 'F4', 'F#4', 'D3', 'F4', 'F#4', 'G4', ...
#        list(['D5', 'B-2', 'D4', 'D5', '5.10', 'D5', 'D4', 'B-4', 'D3', 'F4', 'B-4', '5.10', 'F4', 'A4', 'C3', 'E-4', 'A4', '5.9', 'A4', 'E-4', 'A4', 'E-5', 'F2', 'C4', '5.9', 'C4', 'D5', 'B-2', 'D4', 'D5', '5.10', 'D5', 'D4', 'D5', 'E-2', 'G4', 'C4', 'G4', '3.7.10', 'C4', 'C5', 'E2', 'B4', 'C4', 'C5', 'B4', '4.7.10', 'C5', 'D5', 'C4', 'C5', 'F4', 'F2', 'C4', 'F3', 'A3', 'D4', 'B-3', 'E-4', 'C4', '2', 'B-2', 'D4', '2', '5.10', '2', 'D4', '10', 'D3', 'F4', '10', '5.10', 'F4', '9', 'C3', 'E-4', '9', '5.9', '9', 'E-4', 'A5', '3', 'F2', 'C4', '5.9', 'C4', '2', 'B-2', 'D4', '2', '5.10', '2', 'D4', '7', 'E2', 'C#4', 'G5', 'G6', '4.7.10', 'B-5', 'C#4', 'C6', 'B-5', 'B-3', '0.5', 'A5', 'A3', 'G5', 'G3', 'A5', 'A3', '0.5', '10.2', 'B-2', 'B-3', '2.5', 'B-3', 'D5', 'B-2', 'D4', 'D5', '5.10', 'D5', 'D4', 'B-4', 'D3', 'F4', 'B-4', '5.10', 'F4', 'A4', 'C3', 'E-4', 'A4', '5.9', 'A4', 'E-4', 'A4', 'E-5', 'F2', 'C4', '5.9', 'C4', 'D5', 'B-2', 'D4', 'D5', '5.10', 'D5', 'D4', 'D5', 'E-2', 'G4', 'C4', 'G4', '3.7.10', 'C4', 'C5', 'E2', 'B4', 'C4', 'C5', 'B4', '4.7.10', 'C5', 'D5', 'C4', 'C5', 'F4', 'F2', 'C4', 'F3', 'A3', 'D4', 'B-3', 'E-4', 'C4', '2', 'B-2', 'D4', '2', '5.10', '2', 'D4', '10', 'D3', 'F4', '10', '5.10', 'F4', '9', 'C3', 'E-4', '9', '5.9', '9', 'E-4', 'A5', '3', 'F2', 'C4', '5.9', 'C4', '2', 'B-2', 'D4', '2', '5.10', '2', 'D4', '7', 'E2', 'C#4', 'G5', 'G6', '4.7.10', 'B-5', 'C#4', 'C6', 'B-5', '0.5', 'B-3', 'A5', 'A3', 'G5', 'G3', 'A5', 'A3', '0.5', '10.2', 'B-2', 'B-3', '2.5', 'B-3', '2.6.9', '2', 'D4', '2.6.9', '6.9', '2.6.9', 'D4', '7.10.2', 'G2', 'B-3', '7.10.2', '2.7', 'B-3', '7.10.2', 'G2', 'B-3', '10.0', '9.2', '2.7', '2.7', 'B-3', '4.7', 'C5', 'C2', 'G3', '0.4', 'B-4', 'G3', '5.9.0', 'F2', 'A3', '5.9.0', '0.5', '5.9.0', 'A3', '2.5.7', 'B-1', 'G3', '2.5.7', '2.5', 'G3', 'G4', 'C4', 'E4', 'C2', 'A4', 'C3', 'G3', 'B-4', '5.9', 'A3', '4.7', 'B-3', 'F4', 'F2', 'C4', 'F3', 'A3', 'D4', 'B-3', 'E-4', 'C4', '2', 'B-2', 'D4', '2', '5.10', '2', 'D4', '10', 'D3', 'F4', '10', '8.10', 'F4', 'B-5', 'C3', 'E-4', '10.0', 'A5', '7.10', 'C6', 'E-4', 'B-5', '7', 'E3', 'G4', '10.1', 'G4', 'G2', 'C4', '7.10', 'C4', '10.2.5', 'F2', 'D4', '10.2.5', '5.10', 'D4', 'C5', 'B-4', 'F2', 'A4', 'C4', 'G4', 'A4', 'F3', 'C4', '10.2', 'B-2', 'B-3', '2.5', 'B-3', '2.6.9', '2', 'D4', '2.6.9', '6.9', '2.6.9', 'D4', '7.10.2', 'G2', 'B-3', '7.10.2', '2.7', 'B-3', '7.10.2', 'G2', 'B-3', '10.0', '9.2', '2.7', '2.7', 'B-3', '4.7', 'C5', 'C2', 'G3', '0.4', 'B-4', 'G3', '5.9.0', 'F2', 'A3', '5.9.0', '0.5', '5.9.0', 'A3', '2.5.7', 'B-1', 'G3', '2.5.7', '2.5', 'G3', 'C4', 'E4', 'G4', 'C2', 'A4', 'G3', 'C3', 'B-4', '5.9', 'A3', '4.7', 'B-3', 'F4', 'F2', 'C4', 'F3', 'A3', 'D4', 'B-3', 'E-4', 'C4', '2', 'B-2', 'D4', '2', '5.10', '2', 'D4', '10', 'D3', 'F4', '10', '8.10', 'F4', 'B-5', 'C3', 'E-4', '10.0', 'A5', '7.10', 'C6', 'E-4', 'B-5', '7', 'E3', 'G4', '10.1', 'G4', 'G2', 'C4', '7.10', 'C4', '10.2.5', 'F2', 'D4', '10.2.5', '5.10', 'D4', 'B-4', 'C5', 'F2', 'A4', 'C4', 'G4', 'A4', 'F3', 'C4', '10.2', 'B-2', 'B-3', '2.5', 'B-3', 'C5', 'B-4', 'F2', 'A4', 'C4', 'G4', 'A4', 'F3', 'C4', '10.2', 'B-2', 'B-3', 'F3', 'B-3', 'D3', 'C4', 'B-3', 'F1', 'A3', 'C3', 'G3', 'A3', 'F2', 'C3', '10.2', '5.10', 'D5', 'B-2', 'D4', 'F4', 'F3', 'D5', 'D5', 'D4', 'F4', 'F3', 'D5', 'C5', 'D3', 'D4', 'F4', 'F3', 'B-4', 'B-4', 'D4', 'F4', 'F3', 'C5', 'B-4', 'C3', 'E-4', 'F4', 'F3', 'A4', 'C5', 'F4', 'A4', 'F3', 'D5', 'E-5', 'F2', 'A4', 'C5', 'F3', 'F#5', 'G5', 'A4', 'C5', 'F3', 'E-5', 'D5', 'D3', 'F#4', 'A4', 'A3', 'E-5', 'D5', 'F#4', 'A4', 'A3', 'C5', 'C5', 'D3', 'F4', 'G#4', 'G#3', 'C5', 'B4', 'F4', 'G#4', 'G#3', 'B4', 'B4', 'E-3', 'E-4', 'G4', 'G3', 'C5', 'E-5', 'E-4', 'F#4', 'F#3', 'C5', 'B-4', 'F2', 'D4', 'F4', 'F3', 'B-4', 'A4', 'C4', 'F4', 'F3', 'A4', 'D5', 'B-2', 'D4', 'F4', 'F3', 'D5', 'D5', 'D4', 'F4', 'F3', 'D5', 'C5', 'D3', 'D4', 'F4', 'F3', 'B-4', 'B-4', 'D4', 'F4', 'F3', 'C5', 'B-4', 'C3', 'E-4', 'F4', 'F3', 'A4', 'C5', 'F4', 'A4', 'F3', 'D5', 'E-5', 'F2', 'A4', 'C5', 'F3', 'F#5', 'G5' ...
#        list(['8.0', '5', 'F3', '5.8.0', 'F3', '5.8.0', '5', '8.0', 'F3', '8.0', 'F3', '10.1.5', '5', '10.1', 'F3', '10.1', 'F3', '5.8.0', '5', '8.0', 'F3', '8.0', 'F3', '8.0', '5', 'F2', '5.8.0', 'F2', '5.8.0', '5', '8.0', 'F2', '8.0', 'F2', '10.1.5', '5', '10.1', 'F2', '10.1', 'F2', '5.8.0', '5', '8.0', 'F2', '8.0', 'F2', '5.8.11', 'F3', '8.11.2', 'D3', '8.11.2', 'D3', '0.3.7', 'E-3', '7.0', 'C3', '7.0', 'C3', '2.7', 'B2', '7.11.2', 'G2', '7.11.2', 'G2', '3.7', 'C3', '0.3.7', 'G2', '0.3.7', 'G2', '5.7', 'D3', '7', 'G2', '7', 'G2', 'E-3', '7', 'G2', '7', 'G2', '7', 'E-3', '5.8', '1', '5.8', '1', '5.8', '1', '5.8', '1', '8.1', '5', '8.1', '5.8', '8.1', '5.8', '8.1', '5.8', '0.3', '6.8', '0.3', '6.8', '0.3', '6.8', '1', '1.5.8', '5.8.11', '1', '5.8.0', '0', '0.4.7', '0', '8.0', '5', 'F3', '5.8.0', 'F3', '5.8.0', '5', '8.0', 'F3', '8.0', 'F3', '10.1.5', '5', '10.1', 'F3', '10.1', 'F3', '5.8.0', '5', '8.0', 'F3', '8.0', 'F3', '8.0', '5', 'F2', '5.8.0', 'F2', '5.8.0', '5', '8.0', 'F2', '8.0', 'F2', '10.1.5', '5', '10.1', 'F2', '10.1', 'F2', '5.8.0', '5', '8.0', 'F2', '8.0', 'F2', '5.8.11', 'F3', '8.11.2', 'D3', '8.11.2', 'D3', '0.3.7', 'E-3', '7.0', 'C3', '7.0', 'C3', '2.7', 'B2', '7.11.2', 'G2', '7.11.2', 'G2', '3.7', 'C3', '0.3.7', 'G2', '0.3.7', 'G2', '5.7', 'D3', '7', 'G2', '7', 'G2', 'E-3', '7', 'G2', '7', 'G2', '7', 'E-3', '5.8', '1', '5.8', '1', '5.8', '1', '5.8', '1', '8.1', '5', '8.1', '5.8', '8.1', '5.8', '8.1', '5.8', '0.3', '6.8', '0.3', '6.8', '0.3', '6.8', '1', '1.5.8', '5.8.11', '1', '5.8.0', '0', '0.4.7', '0', '10.0', '10.0', '7.0', '7.0', '7.0', '7.0', '8.0', '8.0', '0.5', '0.5', '0.5', '0.5', '6.8', '6.8', '8.0', '8.0', '8.0', '8.0', '5.8', '1', '1.5.8', '8.1', '6.8', '6.8', '8.0', '8.0', '8.0', '8.0', '5.8', '1', '1.5.8', '8.1', '3.5', '3.5', '0.5', '0.5', '0.5', '0.5', '1.5', '1.5', '5.10', '5.10', '5.10', '5.10', '11.1', '11.1', '1.5', '1.5', '1.5', '1.5', '10.1', '6', '6.10.1', '1.6', '11.1', '11.1', '1.5', '1.5', '1.5', '1.5', '10.1', '6', '6.10.1', '1.6', 'B-5', 'C#3', 'B-4', '1.6', 'F#3', 'B-4', 'F#5', 'F#3', 'F#4', '11.2', 'B3', 'F#4', 'E5', 'F#2', 'G4', '10.1', 'F#3', 'G4', '11.1', '6', 'F#4', '11.2', '6.11', 'F#4', 'G5', 'F#3', 'B-4', '1.4', 'G4', 'B-4', '1.6', '6', 'B-4', '2.6', '6.11', 'B4', 'B5', 'D3', 'B4', '2.7', 'G3', 'B4', 'G5', 'G3', 'G4', '0.3', 'C4', 'G4', 'F5', 'G2', 'G#4', '11.2', 'G3', 'G#4', '0.2', '7', 'G4', '0.3', '7.0', 'G4', 'G#5', 'G3', 'B4', '2.5', 'G#4', 'B4', '2.7', '7', 'B4', '3.7', '7.0', 'C5', 'B-4', 'G4', 'E-5', 'D5', 'E-4', 'E-5', 'E-5', 'E-4', 'G#5', 'G5', '11.3', 'G#5', 'E-6', '1.3', 'E-5', 'G5', '10.3', 'E-5', 'E-5', '10.3', 'G#5', 'G5', '11.3', 'G#5', 'F#5', 'E4', 'F#4', 'B-4', 'C#4', 'F#4', 'F#4', 'C#4', 'B4', 'B-4', 'E-4', 'B4', 'B4', 'G#4', 'E5', 'E-5', 'E4', 'E5', 'E5', 'E4', 'A5', 'G#5', '0.4', 'A5', 'E6', '2.4', 'E5', 'G#5', '11.4', 'E5', 'E5', '11.4', 'A5', 'G#5', '0.4', 'A5', 'G5', 'F4', 'G4', 'B4', 'D4', 'G4', 'G4', 'D4', 'C5', 'B4', 'E4', 'C5', 'C#5', 'C#4', '0.1', '0.1', '10.1', '10.1', '10.1', '10.1', '8.1', '8.1', '1.7', '1.7', '7.10.1', '1.7', '1.5.8', '1.5', '1.4.7', '1.4', '7.10.0', '0', '5.8.0', 'C3', '0.4.7', 'C3', 'C#5', 'C#4', '0.1', '0.1', '10.1', '10.1', '10.1', '10.1', '8.1', '8.1', '1.7', '1.7', '7.10.1', '1.7', '1.5.8', '1.5', '1.4.7', '1.4', '7.10.0', '0', '5.8.0', 'C3', '0.4.7', 'C3', '7.10.1', '1.7', '1.5.8', '1.5', '1.4.7', '1.4', '7.10.0', '0', '5.8.0', 'C3', '0.4.7', 'C3', 'C4', 'C3', 'C#4', 'C#3', 'C4', 'C3', 'C#4', 'C#3', 'C4', 'C3', 'D4', 'D3', 'E4', 'E3', 'F4', 'F3', 'E4', 'E3', 'F4', 'F3', 'E4', 'E3', 'F#4', 'F#3', 'G4', 'G3', 'G#4', 'G#3', 'G4', 'G3', 'B-4', 'B-3', 'G#4', 'G#3', 'C#5', 'C#4', 'C5', 'C4', 'D5', 'D4', 'E-5', 'E-4', 'E5', 'E4', 'F5', 'F4', 'G5', 'G4', '8.0', '5', 'F3', '5.8.0', 'F3', '5.8.0', '5', '8.0', 'F3', '8.0', 'F3', '10.1.5', '5', '10.1', 'F3', '10.1', 'F3', '5.8.0', '5', '8.0', 'F3', '8.0', 'F3', '8.0', '5', 'F2', '5.8.0', 'F2', '5.8.0', '5', '8.0', 'F2', '8.0', 'F2', '10.1.5', '5', '10.1', 'F2', '10.1', 'F2', '5.8. ...
#       dtype=object)

# %%
no_of_timesteps = 32
x = []
y = []

for note_ in new_music:
    for i in range(0, len(note_) - no_of_timesteps, 1):

        #preparing input and output sequences
        input_ = note_[i:i + no_of_timesteps]
        output = note_[i + no_of_timesteps]

        x.append(input_)
        y.append(output)

x=np.array(x)
y=np.array(y)

# %%
y
# Out:
# array(['11.2.5.7', '7', '11.2.5.7', ..., '5', '5', 'F3'], dtype='<U8')

# %%
x
# Out:
# array([['0.4.7', '7.0', '0.4.7', ..., '7', '11.2.5.7', '7'],
#        ['7.0', '0.4.7', '7.0', ..., '11.2.5.7', '7', '11.2.5.7'],
#        ['0.4.7', '7.0', '0.4.7', ..., '7', '11.2.5.7', '7'],
#        ...,
#        ['7.0', '5.9', '0.5', ..., '7.10', '0.4', '5.9.0'],
#        ['5.9', '0.5', '5.9', ..., '0.4', '5.9.0', '5'],
#        ['0.5', '5.9', '0.5', ..., '5.9.0', '5', '5']], dtype='<U8')

# %%
unique_x=list(set(x.ravel()))
x_note_to_int=dict((note_,number) for number,note_ in enumerate(unique_x))

# %%
x_note_to_int
# Out:
# {'B2': 0,
#  '4.8': 1,
#  '4.7.9': 2,
#  'E-3': 3,
#  '8.1': 4,
#  '7.9.1': 5,
#  'D3': 6,
#  'E2': 7,
#  '0': 8,
#  '2.4': 9,
#  '3.6': 10,
#  '4.7.11': 11,
#  '2': 12,
#  '1.4.7': 13,
#  'B-4': 14,
#  'C4': 15,
#  'C#6': 16,
#  'B-2': 17,
#  '11.2.6': 18,
#  '10.1.5': 19,
#  '7.11': 20,
#  '10.2.5': 21,
#  '5.9.0': 22,
#  'F#2': 23,
#  '5': 24,
#  '7.10.2': 25,
#  '0.4': 26,
#  'C2': 27,
#  '5.8': 28,
#  'A5': 29,
#  'F1': 30,
#  '2.8': 31,
#  '11.3': 32,
#  '6.11': 33,
#  'E4': 34,
#  'B5': 35,
#  'F2': 36,
#  '10.11': 37,
#  '6.9': 38,
#  '2.6': 39,
#  '11': 40,
#  '4': 41,
#  'B-1': 42,
#  '10.1.3': 43,
#  '5.8.0': 44,
#  'E6': 45,
#  'G1': 46,
#  'B-6': 47,
#  'B1': 48,
#  '0.2': 49,
#  'G5': 50,
#  'F#6': 51,
#  'A1': 52,
#  '3.8': 53,
#  '5.9': 54,
#  '0.4.7': 55,
#  'F6': 56,
#  '11.4': 57,
#  'C3': 58,
#  'D5': 59,
#  '0.3.5': 60,
#  '4.8.11': 61,
#  '1': 62,
#  '1.5': 63,
#  'E-6': 64,
#  '8': 65,
#  'C6': 66,
#  '0.3': 67,
#  '1.3': 68,
#  '3.6.9': 69,
#  'D6': 70,
#  'G#5': 71,
#  'C7': 72,
#  'G#3': 73,
#  '1.5.8': 74,
#  '4.7.10': 75,
#  'C#5': 76,
#  '0.2.6': 77,
#  '9.0.4': 78,
#  '8.11': 79,
#  'G3': 80,
#  '5.7': 81,
#  '11.2.5.7': 82,
#  '0.3.7': 83,
#  '0.5': 84,
#  '8.11.3': 85,
#  '5.10': 86,
#  '0.3.6': 87,
#  'C#2': 88,
#  '1.4': 89,
#  'B-5': 90,
#  '4.6': 91,
#  '10.1': 92,
#  '3': 93,
#  '6.8': 94,
#  '3.6.8': 95,
#  'B3': 96,
#  '6': 97,
#  'C#3': 98,
#  'E-4': 99,
#  '6.10.1': 100,
#  '9.11': 101,
#  'E3': 102,
#  '6.10': 103,
#  '7.0': 104,
#  'D2': 105,
#  '8.11.2': 106,
#  'E5': 107,
#  '10.0': 108,
#  '3.9': 109,
#  'G#6': 110,
#  'G#4': 111,
#  '10.2': 112,
#  '7.10': 113,
#  '11.1': 114,
#  '9.1': 115,
#  'B-3': 116,
#  '6.9.1': 117,
#  '9.10': 118,
#  '9.0.2': 119,
#  'F4': 120,
#  'A4': 121,
#  'G#1': 122,
#  '4.10': 123,
#  '2.5.7': 124,
#  'F#3': 125,
#  '1.4.7.10': 126,
#  '9.2': 127,
#  '3.6.10': 128,
#  '8.10': 129,
#  'F#4': 130,
#  '7': 131,
#  '2.6.9': 132,
#  '9.0': 133,
#  'C#4': 134,
#  '1.7': 135,
#  '2.7': 136,
#  'D4': 137,
#  '11.3.6': 138,
#  '8.0.3': 139,
#  'G2': 140,
#  'E-5': 141,
#  '9': 142,
#  '3.7.10': 143,
#  'A2': 144,
#  '2.5.9': 145,
#  '3.7': 146,
#  'G4': 147,
#  'A6': 148,
#  '7.8': 149,
#  '10.1.4': 150,
#  '2.5': 151,
#  '4.9': 152,
#  '4.7': 153,
#  'G#2': 154,
#  'A3': 155,
#  'B4': 156,
#  '0.1': 157,
#  'F3': 158,
#  '7.9': 159,
#  '1.6': 160,
#  'F5': 161,
#  '1.4.8': 162,
#  '9.1.4': 163,
#  '8.0': 164,
#  '7.11.2': 165,
#  '2.4.8': 166,
#  '3.4': 167,
#  '0.6': 168,
#  'E-2': 169,
#  '7.10.1': 170,
#  '11.2.4': 171,
#  '10': 172,
#  'G6': 173,
#  '5.11': 174,
#  '11.2': 175,
#  '10.3': 176,
#  '3.5': 177,
#  '7.10.0': 178,
#  'F#5': 179,
#  '5.8.11': 180,
#  'C5': 181}

# %%
x_seq=[]
for i in x:
    temp=[]
    for j in i:
        #assigning unique integer to every note
        temp.append(x_note_to_int[j])
    x_seq.append(temp)

x_seq = np.array(x_seq)

# %%
unique_y = list(set(y))
y_note_to_int = dict((note_, number) for number, note_ in enumerate(unique_y))
y_seq=np.array([y_note_to_int[i] for i in y])

# %%
x_seq
# Out:
# array([[ 55, 104,  55, ..., 131,  82, 131],
#        [104,  55, 104, ...,  82, 131,  82],
#        [ 55, 104,  55, ..., 131,  82, 131],
#        ...,
#        [104,  54,  84, ..., 113,  26,  22],
#        [ 54,  84,  54, ...,  26,  22,  24],
#        [ 84,  54,  84, ...,  22,  24,  24]])

# %%
y_seq
# Out:
# array([ 82, 131,  82, ...,  24,  24, 158])

# %%
from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(x_seq,y_seq,test_size=0.2,random_state=0)

# %%
def lstm():
  model = Sequential()
  model.add(LSTM(128,return_sequences=True))
  model.add(LSTM(128))
  model.add(Dense(256))
  model.add(Activation('relu'))
  model.add(Dense(n_vocab))
  model.add(Activation('softmax'))
  model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')
  return model

# %%
from keras.layers import *
from keras.models import *
from keras.callbacks import *
import keras.backend as K

K.clear_session()
model = Sequential()

#embedding layer
model.add(Embedding(len(unique_x), 100, input_length=32,trainable=True))

model.add(Conv1D(64,3, padding='causal',activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPool1D(2))

model.add(Conv1D(128,3,activation='relu',dilation_rate=2,padding='causal'))
model.add(Dropout(0.2))
model.add(MaxPool1D(2))

model.add(Conv1D(256,3,activation='relu',dilation_rate=4,padding='causal'))
model.add(Dropout(0.2))
model.add(MaxPool1D(2))

#model.add(Conv1D(256,5,activation='relu'))
model.add(GlobalMaxPool1D())

model.add(Dense(256, activation='relu'))
model.add(Dense(len(unique_y), activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 32, 100)           18200
#
#  conv1d (Conv1D)             (None, 32, 64)            19264
#
#  dropout (Dropout)           (None, 32, 64)            0
#
#  max_pooling1d (MaxPooling1  (None, 16, 64)            0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 16, 128)           24704
#
#  dropout_1 (Dropout)         (None, 16, 128)           0
#
#  max_pooling1d_1 (MaxPoolin  (None, 8, 128)            0
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 8, 256)            98560
#
#  dropout_2 (Dropout)         (None, 8, 256)            0
#
#  max_pooling1d_2 (MaxPoolin  (None, 4, 256)            0
#  g1D)
#
#  global_max_pooling1d (Glob  (None, 256)               0
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 256)               65792
#
#  dense_1 (Dense)             (None, 182)               46774
#
# =================================================================
# Total params: 273294 (1.04 MB)
# Trainable params: 273294 (1.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
mc=ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True,verbose=1)

# %%
history = model.fit(np.array(x_tr),np.array(y_tr),batch_size=128,epochs=50, validation_data=(np.array(x_val),np.array(y_val)),verbose=1, callbacks=[mc])
# Out:
# Epoch 1/50
# 491/492 [============================>.] - ETA: 0s - loss: 4.3226
# Epoch 1: val_loss improved from inf to 4.08156, saving model to best_model.h5
# 492/492 [==============================] - 26s 49ms/step - loss: 4.3224 - val_loss: 4.0816
# Epoch 2/50
#   3/492 [..............................] - ETA: 18s - loss: 3.8193
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 492/492 [==============================] - ETA: 0s - loss: 3.7883
# Epoch 2: val_loss improved from 4.08156 to 3.85172, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 3.7883 - val_loss: 3.8517
# Epoch 3/50
# 491/492 [============================>.] - ETA: 0s - loss: 3.6147
# Epoch 3: val_loss improved from 3.85172 to 3.70235, saving model to best_model.h5
# 492/492 [==============================] - 24s 49ms/step - loss: 3.6150 - val_loss: 3.7024
# Epoch 4/50
# 492/492 [==============================] - ETA: 0s - loss: 3.4882
# Epoch 4: val_loss improved from 3.70235 to 3.58082, saving model to best_model.h5
# 492/492 [==============================] - 22s 46ms/step - loss: 3.4882 - val_loss: 3.5808
# Epoch 5/50
# 492/492 [==============================] - ETA: 0s - loss: 3.3861
# Epoch 5: val_loss improved from 3.58082 to 3.51575, saving model to best_model.h5
# 492/492 [==============================] - 23s 46ms/step - loss: 3.3861 - val_loss: 3.5158
# Epoch 6/50
# 491/492 [============================>.] - ETA: 0s - loss: 3.3050
# Epoch 6: val_loss improved from 3.51575 to 3.47240, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 3.3050 - val_loss: 3.4724
# Epoch 7/50
# 492/492 [==============================] - ETA: 0s - loss: 3.2306
# Epoch 7: val_loss improved from 3.47240 to 3.39595, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 3.2306 - val_loss: 3.3959
# Epoch 8/50
# 491/492 [============================>.] - ETA: 0s - loss: 3.1735
# Epoch 8: val_loss improved from 3.39595 to 3.35007, saving model to best_model.h5
# 492/492 [==============================] - 22s 45ms/step - loss: 3.1736 - val_loss: 3.3501
# Epoch 9/50
# 491/492 [============================>.] - ETA: 0s - loss: 3.1131
# Epoch 9: val_loss improved from 3.35007 to 3.32130, saving model to best_model.h5
# 492/492 [==============================] - 23s 46ms/step - loss: 3.1130 - val_loss: 3.3213
# Epoch 10/50
# 491/492 [============================>.] - ETA: 0s - loss: 3.0580
# Epoch 10: val_loss improved from 3.32130 to 3.28013, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 3.0581 - val_loss: 3.2801
# Epoch 11/50
# 491/492 [============================>.] - ETA: 0s - loss: 3.0166
# Epoch 11: val_loss improved from 3.28013 to 3.25839, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 3.0169 - val_loss: 3.2584
# Epoch 12/50
# 492/492 [==============================] - ETA: 0s - loss: 2.9718
# Epoch 12: val_loss improved from 3.25839 to 3.23886, saving model to best_model.h5
# 492/492 [==============================] - 22s 44ms/step - loss: 2.9718 - val_loss: 3.2389
# Epoch 13/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.9397
# Epoch 13: val_loss improved from 3.23886 to 3.18433, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 2.9395 - val_loss: 3.1843
# Epoch 14/50
# 492/492 [==============================] - ETA: 0s - loss: 2.8992
# Epoch 14: val_loss improved from 3.18433 to 3.15794, saving model to best_model.h5
# 492/492 [==============================] - 24s 49ms/step - loss: 2.8992 - val_loss: 3.1579
# Epoch 15/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.8636
# Epoch 15: val_loss improved from 3.15794 to 3.14736, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 2.8636 - val_loss: 3.1474
# Epoch 16/50
# 492/492 [==============================] - ETA: 0s - loss: 2.8321
# Epoch 16: val_loss improved from 3.14736 to 3.13576, saving model to best_model.h5
# 492/492 [==============================] - 22s 45ms/step - loss: 2.8321 - val_loss: 3.1358
# Epoch 17/50
# 492/492 [==============================] - ETA: 0s - loss: 2.8048
# Epoch 17: val_loss improved from 3.13576 to 3.11776, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 2.8048 - val_loss: 3.1178
# Epoch 18/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.7738
# Epoch 18: val_loss improved from 3.11776 to 3.08385, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 2.7738 - val_loss: 3.0839
# Epoch 19/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.7525
# Epoch 19: val_loss did not improve from 3.08385
# 492/492 [==============================] - 23s 46ms/step - loss: 2.7526 - val_loss: 3.0845
# Epoch 20/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.7286
# Epoch 20: val_loss improved from 3.08385 to 3.05020, saving model to best_model.h5
# 492/492 [==============================] - 22s 44ms/step - loss: 2.7287 - val_loss: 3.0502
# Epoch 21/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.7107
# Epoch 21: val_loss improved from 3.05020 to 3.03125, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 2.7106 - val_loss: 3.0313
# Epoch 22/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.6947
# Epoch 22: val_loss improved from 3.03125 to 3.02792, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 2.6947 - val_loss: 3.0279
# Epoch 23/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.6663
# Epoch 23: val_loss improved from 3.02792 to 3.00063, saving model to best_model.h5
# 492/492 [==============================] - 22s 45ms/step - loss: 2.6661 - val_loss: 3.0006
# Epoch 24/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.6513
# Epoch 24: val_loss did not improve from 3.00063
# 492/492 [==============================] - 22s 45ms/step - loss: 2.6512 - val_loss: 3.0007
# Epoch 25/50
# 492/492 [==============================] - ETA: 0s - loss: 2.6381
# Epoch 25: val_loss improved from 3.00063 to 2.98878, saving model to best_model.h5
# 492/492 [==============================] - 24s 50ms/step - loss: 2.6381 - val_loss: 2.9888
# Epoch 26/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.6234
# Epoch 26: val_loss improved from 2.98878 to 2.97052, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 2.6232 - val_loss: 2.9705
# Epoch 27/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.6084
# Epoch 27: val_loss did not improve from 2.97052
# 492/492 [==============================] - 22s 45ms/step - loss: 2.6085 - val_loss: 2.9751
# Epoch 28/50
# 492/492 [==============================] - ETA: 0s - loss: 2.5985
# Epoch 28: val_loss improved from 2.97052 to 2.95797, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 2.5985 - val_loss: 2.9580
# Epoch 29/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.5841
# Epoch 29: val_loss improved from 2.95797 to 2.94848, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 2.5840 - val_loss: 2.9485
# Epoch 30/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.5650
# Epoch 30: val_loss did not improve from 2.94848
# 492/492 [==============================] - 23s 46ms/step - loss: 2.5649 - val_loss: 2.9614
# Epoch 31/50
# 492/492 [==============================] - ETA: 0s - loss: 2.5582
# Epoch 31: val_loss improved from 2.94848 to 2.93654, saving model to best_model.h5
# 492/492 [==============================] - 22s 45ms/step - loss: 2.5582 - val_loss: 2.9365
# Epoch 32/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.5498
# Epoch 32: val_loss improved from 2.93654 to 2.92368, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 2.5497 - val_loss: 2.9237
# Epoch 33/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.5351
# Epoch 33: val_loss improved from 2.92368 to 2.92123, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 2.5349 - val_loss: 2.9212
# Epoch 34/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.5218
# Epoch 34: val_loss improved from 2.92123 to 2.90932, saving model to best_model.h5
# 492/492 [==============================] - 22s 45ms/step - loss: 2.5217 - val_loss: 2.9093
# Epoch 35/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.5172
# Epoch 35: val_loss improved from 2.90932 to 2.89861, saving model to best_model.h5
# 492/492 [==============================] - 22s 45ms/step - loss: 2.5171 - val_loss: 2.8986
# Epoch 36/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.5067
# Epoch 36: val_loss did not improve from 2.89861
# 492/492 [==============================] - 24s 49ms/step - loss: 2.5067 - val_loss: 2.8992
# Epoch 37/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.4984
# Epoch 37: val_loss did not improve from 2.89861
# 492/492 [==============================] - 23s 47ms/step - loss: 2.4985 - val_loss: 2.9073
# Epoch 38/50
# 492/492 [==============================] - ETA: 0s - loss: 2.4864
# Epoch 38: val_loss improved from 2.89861 to 2.88698, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 2.4864 - val_loss: 2.8870
# Epoch 39/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.4856
# Epoch 39: val_loss improved from 2.88698 to 2.88459, saving model to best_model.h5
# 492/492 [==============================] - 23s 46ms/step - loss: 2.4858 - val_loss: 2.8846
# Epoch 40/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.4762
# Epoch 40: val_loss did not improve from 2.88459
# 492/492 [==============================] - 23s 48ms/step - loss: 2.4762 - val_loss: 2.8856
# Epoch 41/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.4692
# Epoch 41: val_loss improved from 2.88459 to 2.87908, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 2.4694 - val_loss: 2.8791
# Epoch 42/50
# 492/492 [==============================] - ETA: 0s - loss: 2.4579
# Epoch 42: val_loss improved from 2.87908 to 2.87466, saving model to best_model.h5
# 492/492 [==============================] - 22s 45ms/step - loss: 2.4579 - val_loss: 2.8747
# Epoch 43/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.4513
# Epoch 43: val_loss improved from 2.87466 to 2.84795, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 2.4514 - val_loss: 2.8479
# Epoch 44/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.4426
# Epoch 44: val_loss did not improve from 2.84795
# 492/492 [==============================] - 23s 47ms/step - loss: 2.4426 - val_loss: 2.8628
# Epoch 45/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.4365
# Epoch 45: val_loss did not improve from 2.84795
# 492/492 [==============================] - 23s 47ms/step - loss: 2.4365 - val_loss: 2.8623
# Epoch 46/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.4314
# Epoch 46: val_loss did not improve from 2.84795
# 492/492 [==============================] - 22s 45ms/step - loss: 2.4314 - val_loss: 2.8509
# Epoch 47/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.4241
# Epoch 47: val_loss improved from 2.84795 to 2.83779, saving model to best_model.h5
# 492/492 [==============================] - 23s 47ms/step - loss: 2.4242 - val_loss: 2.8378
# Epoch 48/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.4181
# Epoch 48: val_loss did not improve from 2.83779
# 492/492 [==============================] - 24s 49ms/step - loss: 2.4182 - val_loss: 2.8448
# Epoch 49/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.4076
# Epoch 49: val_loss did not improve from 2.83779
# 492/492 [==============================] - 22s 46ms/step - loss: 2.4078 - val_loss: 2.8379
# Epoch 50/50
# 491/492 [============================>.] - ETA: 0s - loss: 2.4090
# Epoch 50: val_loss improved from 2.83779 to 2.82571, saving model to best_model.h5
# 492/492 [==============================] - 22s 46ms/step - loss: 2.4090 - val_loss: 2.8257

# %%
from keras.models import load_model
model=load_model('best_model.h5')

# %%
import random
ind=np.random.randint(0,len(x_val)-1)
random_music=x_val[4]
predictions=[]
for i in range(10):

    random_music = random_music.reshape(1,no_of_timesteps)
    prob=model.predict(random_music)[0]


    y_pred=np.argmax(prob,axis=0)
    predictions.append(y_pred)


    random_music = np.insert(random_music[0],len(random_music[0]),y_pred)
    random_music = random_music[1:]

print(predictions)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# [73, 63, 63, 73, 73, 63, 73, 63, 63, 63]

# %%
x_int_to_note= dict((number,note_) for number,note_ in enumerate(unique_x))
predicted_notes=[x_int_to_note[i] for i in predictions]

# %%
predicted_notes
# Out:
# ['G#3', '1.5', '1.5', 'G#3', 'G#3', '1.5', 'G#3', '1.5', '1.5', '1.5']

# %%
from music21 import midi

def play_generated_music(prediction_output):
    offset = 0
    output_notes = []

    for pattern in prediction_output:
        if ('.' in pattern) or pattern.isdigit():
            notes_in_chord = pattern.split('.')
            notes = []
            for current_note in notes_in_chord:
                cn = int(current_note)
                new_note = note.Note(cn)
                new_note.storedInstrument = instrument.Piano()
                notes.append(new_note)
            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)
        else:
            new_note = note.Note(pattern)
            new_note.offset = offset
            new_note.storedInstrument = instrument.Piano()
            output_notes.append(new_note)
        offset += 0.5  # Adjust the offset to control the timing between notes/chords.

    # Create a stream from the generated notes
    midi_stream = stream.Stream(output_notes)

    # Create a temporary MIDI file for playback
    midi_file_path = 'temp_generated_music.mid'
    midi_stream.write('midi', fp=midi_file_path)

    # Play the temporary MIDI file
    midi_data = midi.translate.midiFilePathToStream(midi_file_path)
    midi_data.show('midi')

# Example usage to play the generated music
play_generated_music(predicted_notes)
# Out:
#         <div id="midiPlayerDiv1496419"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv1496419_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv1496419");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv1496419_play, 2000);
#         } else {
#             midiPlayerDiv1496419_play();
#         }
#         </script>
